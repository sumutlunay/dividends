# %%
import ipystata
from ipystata.config import config_stata
config_stata('/usr/local/bin/stata')
# Out:
# IPyStata is loaded in batch mode.

# %% [markdown]
# ANNUAL

# %% [markdown]
# Model change in dividends

# %%
# %%stata
# adopath++ "/home/kennesaw/Sunay/adofiles"
#
# use "/home/kennesaw/Sunay/Dividends/withinprivates.dta", clear
#
# areg chgdps chgeps, absorb(fyear) robust cluster(gvkey)
# # areg chgaltdps chgalteps, absorb(fyear) robust cluster(gvkey)
#
# areg chgdps chgeps if manag==1, absorb(fyear) robust cluster(gvkey)
# # areg chgaltdps chgalteps if manag==1, absorb(fyear) robust cluster(gvkey)
#
# areg chgdps chgeps if employ==1, absorb(fyear) robust cluster(gvkey)
# # areg chgaltdps chgalteps if employ==1, absorb(fyear) robust cluster(gvkey)
#
# areg chgdps chgeps if pe1==1, absorb(fyear) robust cluster(gvkey)
# # areg chgaltdps chgalteps if pe1==1, absorb(fyear) robust cluster(gvkey)
#
# areg chgdps chgeps if pe2==1, absorb(fyear) robust cluster(gvkey)
# # areg chgaltdps chgalteps if pe2==1, absorb(fyear) robust cluster(gvkey)
# Out:
#   [1]              "/home/kennesaw/Sunay/adofiles"
#   [2]  (BASE)      "/usr/local/sas/stata16/ado/base/"
#   [3]  (SITE)      "/usr/local/sas/ado/"
#   [4]              "."
#   [5]  (PERSONAL)  "~/ado/personal/"
#   [6]  (PLUS)      "~/ado/plus/"
#   [7]  (OLDPLACE)  "~/ado/"
#
# Linear regression, absorbing indicators         Number of obs     =      1,781
# Absorbed variable: fyear                        No. of categories =         35
#                                                 F(   1,    430)   =       9.54
#                                                 Prob > F          =     0.0021
#                                                 R-squared         =     0.0403
#                                                 Adj R-squared     =     0.0211
#                                                 Root MSE          = 36659.9852
#
#                                 (Std. Err. adjusted for 431 clusters in gvkey)
# ...

# %%
# %%stata
# adopath++ "/home/kennesaw/Sunay/adofiles"
#
# use "/home/kennesaw/Sunay/Dividends/levelfull.dta", clear
# areg chgdps chgeps if private==0, absorb(fyear) robust cluster(gvkey)
# areg chgdps chgeps if private==1, absorb(fyear) robust cluster(gvkey)
#
# use "/home/kennesaw/Sunay/Dividends/withinprivates.dta", clear
# areg chgdps chgeps if manag==1, absorb(fyear) robust cluster(gvkey)
# areg chgdps chgeps if employ==1, absorb(fyear) robust cluster(gvkey)
# areg chgdps chgeps if pe1==1, absorb(fyear) robust cluster(gvkey)
# areg chgdps chgeps if pe2==1, absorb(fyear) robust cluster(gvkey)
# Out:
#   [1]              "/home/kennesaw/Sunay/adofiles"
#   [2]  (BASE)      "/usr/local/sas/stata16/ado/base/"
#   [3]  (SITE)      "/usr/local/sas/ado/"
#   [4]              "."
#   [5]  (PERSONAL)  "~/ado/personal/"
#   [6]  (PLUS)      "~/ado/plus/"
#   [7]  (OLDPLACE)  "~/ado/"
#
# Linear regression, absorbing indicators         Number of obs     =    181,341
# Absorbed variable: fyear                        No. of categories =         35
#                                                 F(   1,  19219)   =      85.92
#                                                 Prob > F          =     0.0000
#                                                 R-squared         =     0.0167
#                                                 Adj R-squared     =     0.0165
#                                                 Root MSE          =     0.2674
#
#                              (Std. Err. adjusted for 19,220 clusters in gvkey)
# ...

# %%
# %%stata
# adopath++ "/home/kennesaw/Sunay/adofiles"
#
# use "/home/kennesaw/Sunay/Dividends/levelfull.dta", clear
# reg chgdps chgeps if private==0, robust cluster(gvkey)
# reg chgdps chgeps if private==1, robust cluster(gvkey)
#
# use "/home/kennesaw/Sunay/Dividends/withinprivates.dta", clear
# reg chgdps chgeps if manag==1, robust cluster(gvkey)
# reg chgdps chgeps if employ==1, robust cluster(gvkey)
# reg chgdps chgeps if pe1==1, robust cluster(gvkey)
# reg chgdps chgeps if pe2==1, robust cluster(gvkey)
# Out:
#   [1]              "/home/kennesaw/Sunay/adofiles"
#   [2]  (BASE)      "/usr/local/sas/stata16/ado/base/"
#   [3]  (SITE)      "/usr/local/sas/ado/"
#   [4]              "."
#   [5]  (PERSONAL)  "~/ado/personal/"
#   [6]  (PLUS)      "~/ado/plus/"
#   [7]  (OLDPLACE)  "~/ado/"
#
# Linear regression                               Number of obs     =    181,341
#                                                 F(1, 19219)       =      87.62
#                                                 Prob > F          =     0.0000
#                                                 R-squared         =     0.0080
#                                                 Root MSE          =     .26856
#
#                              (Std. Err. adjusted for 19,220 clusters in gvkey)
# ------------------------------------------------------------------------------
#              |               Robust
#       chgdps |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# ...

# %%
# %%stata
# adopath++ "/home/kennesaw/Sunay/adofiles"
#
# use "/home/kennesaw/Sunay/Dividends/levelfull.dta", clear
# areg chgdps lagdps eps if private==0, absorb(fyear) robust cluster(gvkey)
# areg chgdps lagdps eps if private==1, absorb(fyear) robust cluster(gvkey)
#
# use "/home/kennesaw/Sunay/Dividends/withinprivates.dta", clear
# areg chgdps lagdps eps if manag==1, absorb(fyear) robust cluster(gvkey)
# areg chgdps lagdps eps if employ==1, absorb(fyear) robust cluster(gvkey)
# areg chgdps lagdps eps if pe1==1, absorb(fyear) robust cluster(gvkey)
# areg chgdps lagdps eps if pe2==1, absorb(fyear) robust cluster(gvkey)
# Out:
#   [1]              "/home/kennesaw/Sunay/adofiles"
#   [2]  (BASE)      "/usr/local/sas/stata16/ado/base/"
#   [3]  (SITE)      "/usr/local/sas/ado/"
#   [4]              "."
#   [5]  (PERSONAL)  "~/ado/personal/"
#   [6]  (PLUS)      "~/ado/plus/"
#   [7]  (OLDPLACE)  "~/ado/"
#
# Linear regression, absorbing indicators         Number of obs     =    181,499
# Absorbed variable: fyear                        No. of categories =         35
#                                                 F(   2,  19231)   =     195.98
#                                                 Prob > F          =     0.0000
#                                                 R-squared         =     0.1066
#                                                 Adj R-squared     =     0.1064
#                                                 Root MSE          =     0.2549
#
#                              (Std. Err. adjusted for 19,232 clusters in gvkey)
# ...

# %%
# %%stata
# adopath++ "/home/kennesaw/Sunay/adofiles"
#
# use "/home/kennesaw/Sunay/Dividends/levelfull.dta", clear
# gen incdiv=0
# replace incdiv=1 if chgdps>0
#
# logit incdiv chgeps if private==0, robust cluster(gvkey)
# logit incdiv chgeps if private==1, robust cluster(gvkey)
#
# use "/home/kennesaw/Sunay/Dividends/withinprivates.dta", clear
# gen incdiv=0
# replace incdiv=1 if chgdps>0
#
# logit incdiv chgeps if manag==1, robust cluster(gvkey)
# logit incdiv chgeps if employ==1, robust cluster(gvkey)
# logit incdiv chgeps if pe1==1, robust cluster(gvkey)
# logit incdiv chgeps if pe2==1, robust cluster(gvkey)
# Out:
#   [1]              "/home/kennesaw/Sunay/adofiles"
#   [2]  (BASE)      "/usr/local/sas/stata16/ado/base/"
#   [3]  (SITE)      "/usr/local/sas/ado/"
#   [4]              "."
#   [5]  (PERSONAL)  "~/ado/personal/"
#   [6]  (PLUS)      "~/ado/plus/"
#   [7]  (OLDPLACE)  "~/ado/"
# (44,162 real changes made)
#
# Iteration 0:   log pseudolikelihood = -91648.057
# Iteration 1:   log pseudolikelihood =  -91604.01
# Iteration 2:   log pseudolikelihood = -91603.987
# Iteration 3:   log pseudolikelihood = -91603.987
#
# Logistic regression                             Number of obs     =    182,023
#                                                 Wald chi2(1)      =      71.46
#                                                 Prob > chi2       =     0.0000
# Log pseudolikelihood = -91603.987               Pseudo R2         =     0.0005
#
#                              (Std. Err. adjusted for 19,241 clusters in gvkey)
# ...

# %% [raw]
# QUARTERLY
