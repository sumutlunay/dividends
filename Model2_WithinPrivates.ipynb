# %%
import ipystata
from ipystata.config import config_stata
config_stata('/usr/local/bin/stata')
# Out:
# IPyStata is loaded in batch mode.

# %% [markdown]
# Annual Results

# %% [markdown]
# Dependent Variable Scaled by Assets

# %%
# %%stata
# adopath++ "/home/kennesaw/Sunay/adofiles"
#
# use "/home/kennesaw/Sunay/Dividends/withinprivates.dta", clear
#
# gen group1 = manag+employ
# gen group2 = pe1+pe2
#
# drop if (group1+group2==0)
#
# areg div2 group1 salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# areg repurch2 group1 salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# areg payout2 group1 salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# Out:
#   [1]              "/home/kennesaw/Sunay/adofiles"
#   [2]  (BASE)      "/usr/local/sas/stata16/ado/base/"
#   [3]  (SITE)      "/usr/local/sas/ado/"
#   [4]              "."
#   [5]  (PERSONAL)  "~/ado/personal/"
#   [6]  (PLUS)      "~/ado/plus/"
#   [7]  (OLDPLACE)  "~/ado/"
# (29 observations deleted)
#
# Linear regression, absorbing indicators         Number of obs     =      2,131
# Absorbed variable: fyear                        No. of categories =         42
#                                                 F(   5,    465)   =       2.77
#                                                 Prob > F          =     0.0178
#                                                 R-squared         =     0.1536
#                                                 Adj R-squared     =     0.1349
#                                                 Root MSE          =     0.0431
#
#                                 (Std. Err. adjusted for 466 clusters in gvkey)
# ...

# %% [markdown]
# Dependent Variable Scaled by Operating Income

# %%
# %%stata
# adopath++ "/home/kennesaw/Sunay/adofiles"
#
# use "/home/kennesaw/Sunay/Dividends/withinprivates.dta", clear
#
# gen group1 = manag+employ
# gen group2 = pe1+pe2
#
# drop if (group1+group2==0)
#
# areg div1 group1 salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# areg repurch1 group1 salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# areg payout1 group1 salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# Out:
#   [1]              "/home/kennesaw/Sunay/adofiles"
#   [2]  (BASE)      "/usr/local/sas/stata16/ado/base/"
#   [3]  (SITE)      "/usr/local/sas/ado/"
#   [4]              "."
#   [5]  (PERSONAL)  "~/ado/personal/"
#   [6]  (PLUS)      "~/ado/plus/"
#   [7]  (OLDPLACE)  "~/ado/"
# (29 observations deleted)
#
# Linear regression, absorbing indicators         Number of obs     =      2,131
# Absorbed variable: fyear                        No. of categories =         42
#                                                 F(   5,    465)   =       1.70
#                                                 Prob > F          =     0.1332
#                                                 R-squared         =     0.0655
#                                                 Adj R-squared     =     0.0449
#                                                 Root MSE          =     0.8443
#
#                                 (Std. Err. adjusted for 466 clusters in gvkey)
# ...

# %%
Quarterly Results

# %% [markdown]
# Dependent Variable Scaled by Assets

# %%
# %%stata
# adopath++ "/home/kennesaw/Sunay/adofiles"
#
# use "/home/kennesaw/Sunay/Dividends/withinprivates_q.dta", clear
#
# gen group1 = manag+employ
# gen group2 = pe1+pe2
#
# drop if (group1+group2==0)
# egen quarter=group(datacqtr)
#
# areg div2 group1 salgrowth logat da opprofit, absorb(quarter) robust cluster(gvkey)
#
# areg netrepa group1 salgrowth logat da opprofit, absorb(quarter) robust cluster(gvkey)
# areg grossrepa group1 salgrowth logat da opprofit, absorb(quarter) robust cluster(gvkey)
#
#
# areg payouta group1 salgrowth logat da opprofit, absorb(quarter) robust cluster(gvkey)
# Out:
#   [1]              "/home/kennesaw/Sunay/adofiles"
#   [2]  (BASE)      "/usr/local/sas/stata16/ado/base/"
#   [3]  (SITE)      "/usr/local/sas/ado/"
#   [4]              "."
#   [5]  (PERSONAL)  "~/ado/personal/"
#   [6]  (PLUS)      "~/ado/plus/"
#   [7]  (OLDPLACE)  "~/ado/"
# (148 observations deleted)
# (7 missing values generated)
#
# Linear regression, absorbing indicators         Number of obs     =     10,881
# Absorbed variable: quarter                      No. of categories =        155
#                                                 F(   5,    602)   =       2.40
#                                                 Prob > F          =     0.0359
#                                                 R-squared         =     0.0707
#                                                 Adj R-squared     =     0.0569
#                                                 Root MSE          =     0.0284
#
#                                 (Std. Err. adjusted for 603 clusters in gvkey)
# ...

# %% [markdown]
# Dependent Variable Scaled by Operating Income

# %%
# %%stata
# adopath++ "/home/kennesaw/Sunay/adofiles"
#
# use "/home/kennesaw/Sunay/Dividends/withinprivates_q.dta", clear
#
# gen group1 = manag+employ
# gen group2 = pe1+pe2
#
# drop if (group1+group2==0)
# egen quarter=group(datacqtr)
#
# areg div1 group1 salgrowth logat da opprofit, absorb(quarter) robust cluster(gvkey)
# areg netrepi group1 salgrowth logat da opprofit, absorb(quarter) robust cluster(gvkey)
# areg payouti group1 salgrowth logat da opprofit, absorb(quarter) robust cluster(gvkey)
# Out:
#   [1]              "/home/kennesaw/Sunay/adofiles"
#   [2]  (BASE)      "/usr/local/sas/stata16/ado/base/"
#   [3]  (SITE)      "/usr/local/sas/ado/"
#   [4]              "."
#   [5]  (PERSONAL)  "~/ado/personal/"
#   [6]  (PLUS)      "~/ado/plus/"
#   [7]  (OLDPLACE)  "~/ado/"
# (148 observations deleted)
# (7 missing values generated)
#
# Linear regression, absorbing indicators         Number of obs     =     10,880
# Absorbed variable: quarter                      No. of categories =        155
#                                                 F(   5,    602)   =       1.24
#                                                 Prob > F          =     0.2877
#                                                 R-squared         =     0.0355
#                                                 Adj R-squared     =     0.0211
#                                                 Root MSE          =     0.7447
#
#                                 (Std. Err. adjusted for 603 clusters in gvkey)
# ...
