# %%
import ipystata
from ipystata.config import config_stata
config_stata('/usr/local/bin/stata')
# Out:
# IPyStata is loaded in batch mode.

# %% [markdown]
# Annual Sample

# %%
# %%stata
# adopath++ "/home/kennesaw/Sunay/adofiles"
#
# use "/home/kennesaw/Sunay/Dividends/levelfull.dta", clear
#
# replace manag=0 if missing(manag)
# replace employ=0 if missing(employ)
# replace pe1=0 if missing(pe1)
# replace pe2=0 if missing(pe2)
#
# gen group1 = manag+employ
# gen group2 = pe1+pe2
#
# replace group1=0 if missing(group1)
# replace group2=0 if missing(group2)
#
# gen public=0
# replace public=1 if private==0
#
# areg div2 private salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel replace
#
# gen in_sample=e(sample)
# total private if in_sample==1
# drop in_sample
#
# areg repurch2 private salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total private if in_sample==1
# drop in_sample
#
# areg payout2 private salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total private if in_sample==1
# drop in_sample
#
# areg div2 private salgrowth logat da opprofit loss fcf involat, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total private if in_sample==1
# drop in_sample
#
# areg repurch2 private salgrowth logat da opprofit loss fcf involat, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total private if in_sample==1
# drop in_sample
#
# areg payout2 private salgrowth logat da opprofit loss fcf involat, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total private if in_sample==1
# drop in_sample
#
# /******/
# areg div1 private salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total private if in_sample==1
# drop in_sample
#
# areg repurch1 private salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total private if in_sample==1
# drop in_sample
#
# areg payout1 private salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total private if in_sample==1
# drop in_sample
#
# areg div1 private salgrowth logat da opprofit loss fcf involat, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total private if in_sample==1
# drop in_sample
#
# areg repurch1 private salgrowth logat da opprofit loss fcf involat, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total private if in_sample==1
# drop in_sample
#
# areg payout1 private salgrowth logat da opprofit loss fcf involat, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total private if in_sample==1
# drop in_sample
#
# sum salgrowth logat da opprofit loss fcf involat
# Out:
#   [1]              "/home/kennesaw/Sunay/adofiles"
#   [2]  (BASE)      "/usr/local/sas/stata16/ado/base/"
#   [3]  (SITE)      "/usr/local/sas/ado/"
#   [4]              "."
#   [5]  (PERSONAL)  "~/ado/personal/"
#   [6]  (PLUS)      "~/ado/plus/"
#   [7]  (OLDPLACE)  "~/ado/"
# (201,289 real changes made)
# (201,289 real changes made)
# (201,289 real changes made)
# (201,289 real changes made)
# (0 real changes made)
# (0 real changes made)
# (201,289 real changes made)
#
# Linear regression, absorbing indicators         Number of obs     =    202,775
# Absorbed variable: fyear                        No. of categories =         42
#                                                 F(   5,  19859)   =     436.89
#                                                 Prob > F          =     0.0000
#                                                 R-squared         =     0.0807
#                                                 Adj R-squared     =     0.0805
# ...

# %%
# %%stata
# adopath++ "/home/kennesaw/Sunay/adofiles"
#
# use "/home/kennesaw/Sunay/Dividends/levelfull.dta", clear
#
# replace manag=0 if missing(manag)
# replace employ=0 if missing(employ)
# replace pe1=0 if missing(pe1)
# replace pe2=0 if missing(pe2)
#
# gen group1 = manag+employ
# gen group2 = pe1+pe2
#
# replace group1=0 if missing(group1)
# replace group2=0 if missing(group2)
#
# gen public=0
# replace public=1 if private==0
#
# areg div2 private salgrowth logat da opprofit loss, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel replace
#
# gen in_sample=e(sample)
# total private if in_sample==1
# drop in_sample
#
# areg div2 private salgrowth logat da fcf loss, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total private if in_sample==1
# drop in_sample

# %%
# %%stata
# adopath++ "/home/kennesaw/Sunay/adofiles"
#
# use "/home/kennesaw/Sunay/Dividends/levelfull.dta", clear
#
# replace manag=0 if missing(manag)
# replace employ=0 if missing(employ)
# replace pe1=0 if missing(pe1)
# replace pe2=0 if missing(pe2)
#
# gen group1 = manag+employ
# gen group2 = pe1+pe2
#
# replace group1=0 if missing(group1)
# replace group2=0 if missing(group2)
#
# gen public=0
# replace public=1 if private==0
# areg div2 pe1 pe2 manag employ salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel replace
#
# gen in_sample=e(sample)
# total  pe1 pe2 manag employ if in_sample==1
# drop in_sample
#
# areg repurch2 pe1 pe2 manag employ salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total  pe1 pe2 manag employ if in_sample==1
# drop in_sample
#
# areg payout2 pe1 pe2 manag employ salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total  pe1 pe2 manag employ if in_sample==1
# drop in_sample
#
#
# areg div2 pe1 pe2 manag employ salgrowth logat da opprofit loss fcf involat, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total  pe1 pe2 manag employ if in_sample==1
# drop in_sample
#
# areg repurch2 pe1 pe2 manag employ salgrowth logat da opprofit loss fcf involat, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total  pe1 pe2 manag employ if in_sample==1
# drop in_sample
#
# areg payout2 pe1 pe2 manag employ salgrowth logat da opprofit loss fcf involat, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total  pe1 pe2 manag employ if in_sample==1
# drop in_sample
#
#
# /******/
# areg div1 pe1 pe2 manag employ salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total  pe1 pe2 manag employ if in_sample==1
# drop in_sample
#
# areg repurch1 pe1 pe2 manag employ salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total  pe1 pe2 manag employ if in_sample==1
# drop in_sample
#
# areg payout1 pe1 pe2 manag employ salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total  pe1 pe2 manag employ if in_sample==1
# drop in_sample
#
#
# areg div1 pe1 pe2 manag employ salgrowth logat da opprofit loss fcf involat, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total  pe1 pe2 manag employ if in_sample==1
# drop in_sample
#
# areg repurch1 pe1 pe2 manag employ salgrowth logat da opprofit loss fcf involat, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total  pe1 pe2 manag employ if in_sample==1
# drop in_sample
#
# areg payout1 pe1 pe2 manag employ salgrowth logat da opprofit loss fcf involat, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total  pe1 pe2 manag employ if in_sample==1
# drop in_sample
# Out:
#   [1]              "/home/kennesaw/Sunay/adofiles"
#   [2]  (BASE)      "/usr/local/sas/stata16/ado/base/"
#   [3]  (SITE)      "/usr/local/sas/ado/"
#   [4]              "."
#   [5]  (PERSONAL)  "~/ado/personal/"
#   [6]  (PLUS)      "~/ado/plus/"
#   [7]  (OLDPLACE)  "~/ado/"
# (201,147 real changes made)
# (201,147 real changes made)
# (201,147 real changes made)
# (201,147 real changes made)
# (0 real changes made)
# (0 real changes made)
# (201,147 real changes made)
#
# Linear regression, absorbing indicators         Number of obs     =    202,641
# Absorbed variable: fyear                        No. of categories =         42
#                                                 F(   8,  19853)   =     274.25
#                                                 Prob > F          =     0.0000
#                                                 R-squared         =     0.0808
#                                                 Adj R-squared     =     0.0806
# ...

# %% [markdown]
# Quarterly Sample

# %%
# %%stata
# adopath++ "/home/kennesaw/Sunay/adofiles"
#
# use "/home/kennesaw/Sunay/Dividends/levelfull_q.dta", clear
#
# replace manag=0 if missing(manag)
# replace employ=0 if missing(employ)
# replace pe1=0 if missing(pe1)
# replace pe2=0 if missing(pe2)
#
# gen group1 = manag+employ
# gen group2 = pe1+pe2
#
# replace group1=0 if missing(group1)
# replace group2=0 if missing(group2)
#
# gen public=0
# replace public=1 if private==0
#
# egen quarter=group(datacqtr)
#
# areg div2 private salgrowth logat da opprofit, absorb(quarter) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel replace
#
# gen in_sample=e(sample)
# total private if in_sample==1
# drop in_sample
#
# areg netrepa private salgrowth logat da opprofit, absorb(quarter) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total private if in_sample==1
# drop in_sample
#
# areg payouta private salgrowth logat da opprofit, absorb(quarter) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total private if in_sample==1
# drop in_sample
#
# areg div2 private salgrowth logat da opprofit loss fcf involat, absorb(quarter) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total private if in_sample==1
# drop in_sample
#
# areg netrepa private salgrowth logat da opprofit loss fcf involat, absorb(quarter) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total private if in_sample==1
# drop in_sample
#
# areg payouta private salgrowth logat da opprofit loss fcf involat, absorb(quarter) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total private if in_sample==1
# drop in_sample
#
# /*********/
#
# areg div1 private salgrowth logat da opprofit, absorb(quarter) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total private if in_sample==1
# drop in_sample
#
# areg netrepi private salgrowth logat da opprofit, absorb(quarter) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total private if in_sample==1
# drop in_sample
#
# areg payouti private salgrowth logat da opprofit, absorb(quarter) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total private if in_sample==1
# drop in_sample
#
# areg div1 private salgrowth logat da opprofit loss fcf involat, absorb(quarter) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total private if in_sample==1
# drop in_sample
#
# areg netrepi private salgrowth logat da opprofit loss fcf involat, absorb(quarter) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total private if in_sample==1
# drop in_sample
#
# areg payouti private salgrowth logat da opprofit loss fcf involat, absorb(quarter) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total private if in_sample==1
# drop in_sample
# Out:
#   [1]              "/home/kennesaw/Sunay/adofiles"
#   [2]  (BASE)      "/usr/local/sas/stata16/ado/base/"
#   [3]  (SITE)      "/usr/local/sas/ado/"
#   [4]              "."
#   [5]  (PERSONAL)  "~/ado/personal/"
#   [6]  (PLUS)      "~/ado/plus/"
#   [7]  (OLDPLACE)  "~/ado/"
# (786,507 real changes made)
# (786,507 real changes made)
# (786,507 real changes made)
# (786,507 real changes made)
# (0 real changes made)
# (0 real changes made)
# (786,507 real changes made)
# (787 missing values generated)
#
# Linear regression, absorbing indicators         Number of obs     =    796,796
# Absorbed variable: quarter                      No. of categories =        172
#                                                 F(   5,  22404)   =     403.26
#                                                 Prob > F          =     0.0000
#                                                 R-squared         =     0.0689
#                                                 Adj R-squared     =     0.0687
# ...

# %%
# %%stata
# adopath++ "/home/kennesaw/Sunay/adofiles"
#
# use "/home/kennesaw/Sunay/Dividends/levelfull_q.dta", clear
#
# replace manag=0 if missing(manag)
# replace employ=0 if missing(employ)
# replace pe1=0 if missing(pe1)
# replace pe2=0 if missing(pe2)
#
# gen group1 = manag+employ
# gen group2 = pe1+pe2
#
# replace group1=0 if missing(group1)
# replace group2=0 if missing(group2)
#
# gen public=0
# replace public=1 if private==0
#
# egen quarter=group(datacqtr)
#
# areg div2 pe1 pe2 manag employ salgrowth logat da opprofit, absorb(quarter) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel replace
#
# gen in_sample=e(sample)
# total  pe1 pe2 manag employ if in_sample==1
# drop in_sample
#
# areg netrepa pe1 pe2 manag employ salgrowth logat da opprofit, absorb(quarter) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total  pe1 pe2 manag employ if in_sample==1
# drop in_sample
#
# areg payouta pe1 pe2 manag employ salgrowth logat da opprofit, absorb(quarter) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total  pe1 pe2 manag employ if in_sample==1
# drop in_sample
#
# areg div2 pe1 pe2 manag employ salgrowth logat da opprofit loss fcf involat, absorb(quarter) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total  pe1 pe2 manag employ if in_sample==1
# drop in_sample
#
# areg netrepa pe1 pe2 manag employ salgrowth logat da opprofit loss fcf involat, absorb(quarter) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total  pe1 pe2 manag employ if in_sample==1
# drop in_sample
#
# areg payouta pe1 pe2 manag employ salgrowth logat da opprofit loss fcf involat, absorb(quarter) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total  pe1 pe2 manag employ if in_sample==1
# drop in_sample
#
# /*********/
#
# areg div1 pe1 pe2 manag employ salgrowth logat da opprofit, absorb(quarter) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total  pe1 pe2 manag employ if in_sample==1
# drop in_sample
#
# areg netrepi pe1 pe2 manag employ salgrowth logat da opprofit, absorb(quarter) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total  pe1 pe2 manag employ if in_sample==1
# drop in_sample
#
# areg payouti pe1 pe2 manag employ salgrowth logat da opprofit, absorb(quarter) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total  pe1 pe2 manag employ if in_sample==1
# drop in_sample
#
# areg div1 pe1 pe2 manag employ salgrowth logat da opprofit loss fcf involat, absorb(quarter) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total  pe1 pe2 manag employ if in_sample==1
# drop in_sample
#
# areg netrepi pe1 pe2 manag employ salgrowth logat da opprofit loss fcf involat, absorb(quarter) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total  pe1 pe2 manag employ if in_sample==1
# drop in_sample
#
# areg payouti pe1 pe2 manag employ salgrowth logat da opprofit loss fcf involat, absorb(quarter) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total  pe1 pe2 manag employ if in_sample==1
# drop in_sample
# Out:
#   [1]              "/home/kennesaw/Sunay/adofiles"
#   [2]  (BASE)      "/usr/local/sas/stata16/ado/base/"
#   [3]  (SITE)      "/usr/local/sas/ado/"
#   [4]              "."
#   [5]  (PERSONAL)  "~/ado/personal/"
#   [6]  (PLUS)      "~/ado/plus/"
#   [7]  (OLDPLACE)  "~/ado/"
# (786,507 real changes made)
# (786,507 real changes made)
# (786,507 real changes made)
# (786,507 real changes made)
# (0 real changes made)
# (0 real changes made)
# (786,507 real changes made)
# (787 missing values generated)
#
# Linear regression, absorbing indicators         Number of obs     =    796,796
# Absorbed variable: quarter                      No. of categories =        172
#                                                 F(   8,  22404)   =     252.80
#                                                 Prob > F          =     0.0000
#                                                 R-squared         =     0.0690
#                                                 Adj R-squared     =     0.0688
# ...
