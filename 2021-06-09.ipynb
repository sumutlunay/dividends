# %%
import ipystata
from ipystata.config import config_stata
config_stata('/usr/local/bin/stata')
# Out:
# IPyStata is loaded in batch mode.

# %% [markdown]
# QUARTERLY

# %% [raw]
# Full Model

# %%
# %%stata
# adopath++ "/home/kennesaw/Sunay/adofiles"
#
# use "/home/kennesaw/Sunay/Dividends/levelfull_q.dta", clear
#
# egen quarter=group(datacqtr)
# local controls salgrowth logat da opprofit loss
#
# areg div2 private `controls', absorb(quarter) robust cluster(gvkey)
# areg grossrepa private `controls', absorb(quarter) robust cluster(gvkey)
# areg payouta private `controls', absorb(quarter) robust cluster(gvkey)
# Out:
#   [1]              "/home/kennesaw/Sunay/adofiles"
#   [2]  (BASE)      "/usr/local/sas/stata16/ado/base/"
#   [3]  (SITE)      "/usr/local/sas/ado/"
#   [4]              "."
#   [5]  (PERSONAL)  "~/ado/personal/"
#   [6]  (PLUS)      "~/ado/plus/"
#   [7]  (OLDPLACE)  "~/ado/"
# (743 missing values generated)
#
# Linear regression, absorbing indicators         Number of obs     =    727,212
# Absorbed variable: quarter                      No. of categories =        144
#                                                 F(   6,  21586)   =     415.88
#                                                 Prob > F          =     0.0000
#                                                 R-squared         =     0.0735
#                                                 Adj R-squared     =     0.0733
#                                                 Root MSE          =     0.0150
#
#                              (Std. Err. adjusted for 21,587 clusters in gvkey)
# ...

# %% [raw]
# PSM

# %%
# %%stata
# adopath++ "/home/kennesaw/Sunay/adofiles"
#
# use "/home/kennesaw/Sunay/Dividends/levelfull_q.dta", clear
#
# /***Interest Coverage give problem in logit, I take the log here****/
# gen intcov = log(int_cov)
#
# logit private logat da intcov loss intang ppe growth
# predict p
#
# egen gr=group(datacqtr FFI48)
# gen ps = gr*10+p
#
# set seed 1984
# gen u=uniform()
# sort u
#
# psmatch2 private, pscore(ps) caliper(.1) noreplace neighbor(1)
# gen pair = _id if _treated==0
# replace pair = _n1 if _treated==1
# bysort pair: egen paircount = count(pair)
# drop if paircount !=2
#
# egen quarter=group(datacqtr)
# local controls salgrowth logat da opprofit loss
#
# areg div2 private `controls', absorb(quarter) robust cluster(gvkey)
# areg grossrepa private `controls', absorb(quarter) robust cluster(gvkey)
# areg payouta private `controls', absorb(quarter) robust cluster(gvkey)
# Out:
#   [1]              "/home/kennesaw/Sunay/adofiles"
#   [2]  (BASE)      "/usr/local/sas/stata16/ado/base/"
#   [3]  (SITE)      "/usr/local/sas/ado/"
#   [4]              "."
#   [5]  (PERSONAL)  "~/ado/personal/"
#   [6]  (PLUS)      "~/ado/plus/"
#   [7]  (OLDPLACE)  "~/ado/"
# . gen intcov = log(int_cov)
# (293,952 missing values generated)
#
# Iteration 0:   log likelihood = -46500.941
# Iteration 1:   log likelihood = -42195.681
# Iteration 2:   log likelihood = -40296.755
# Iteration 3:   log likelihood = -40177.387
# Iteration 4:   log likelihood = -40177.312
# Iteration 5:   log likelihood = -40177.312
#
# Logistic regression                             Number of obs     =    426,580
#                                                 LR chi2(7)        =   12647.26
#                                                 Prob > chi2       =     0.0000
# Log likelihood = -40177.312                     Pseudo R2         =     0.1360
#
# ...

# %% [raw]
# Within Privates

# %%
# %%stata
# adopath++ "/home/kennesaw/Sunay/adofiles"
#
# use "/home/kennesaw/Sunay/Dividends/withinprivates_q.dta", clear
#
# gen group1 = manag+employ
# gen group2 = pe1+pe2
#
# drop if (group1+group2==0)
# egen quarter=group(datacqtr)
#
# drop if employ==1
#
# # areg div2 group1 salgrowth logat da opprofit, absorb(quarter) robust cluster(gvkey)
# # areg grossrepa group1 salgrowth logat da opprofit, absorb(quarter) robust cluster(gvkey)
# # areg payouta group1 salgrowth logat da opprofit, absorb(quarter) robust cluster(gvkey)
#
# # areg div2 manag salgrowth logat da opprofit, absorb(quarter) robust cluster(gvkey)
# # areg grossrepa manag salgrowth logat da opprofit, absorb(quarter) robust cluster(gvkey)
# # areg payouta manag salgrowth logat da opprofit, absorb(quarter) robust cluster(gvkey)
#
# # areg div2 c.manag##c.Mgmt_own salgrowth logat da opprofit, absorb(quarter) robust cluster(gvkey)
# # areg grossrepa c.manag##c.Mgmt_own salgrowth logat da opprofit, absorb(quarter) robust cluster(gvkey)
# # areg payouta c.manag##c.Mgmt_own salgrowth logat da opprofit, absorb(quarter) robust cluster(gvkey)
#
# # areg div2 c.manag##c.mgmt_ownership salgrowth logat da opprofit, absorb(quarter) robust cluster(gvkey)
# # areg grossrepa c.manag##c.mgmt_ownership salgrowth logat da opprofit, absorb(quarter) robust cluster(gvkey)
# # areg payouta c.manag##c.mgmt_ownership salgrowth logat da opprofit, absorb(quarter) robust cluster(gvkey)
#
# # areg div2 c.pe1##c.Mgmt_own salgrowth logat da opprofit, absorb(quarter) robust cluster(gvkey)
# # areg grossrepa c.pe1##c.Mgmt_own salgrowth logat da opprofit, absorb(quarter) robust cluster(gvkey)
# # areg payouta c.pe1##c.Mgmt_own salgrowth logat da opprofit, absorb(quarter) robust cluster(gvkey)
#
# # areg div2 c.pe2##c.Mgmt_own salgrowth logat da opprofit, absorb(quarter) robust cluster(gvkey)
# # areg grossrepa c.pe2##c.Mgmt_own salgrowth logat da opprofit, absorb(quarter) robust cluster(gvkey)
# # areg payouta c.pe2##c.Mgmt_own salgrowth logat da opprofit, absorb(quarter) robust cluster(gvkey)
#
# areg div2 Many_PE salgrowth logat da opprofit if group2==1, absorb(quarter) robust cluster(gvkey)
# areg grossrepa Many_PE salgrowth logat da opprofit if group2==1, absorb(quarter) robust cluster(gvkey)
# areg payouta Many_PE salgrowth logat da opprofit if group2==1, absorb(quarter) robust cluster(gvkey)
#
# areg div2 largepe salgrowth logat da opprofit if group2==1, absorb(quarter) robust cluster(gvkey)
# areg grossrepa largepe salgrowth logat da opprofit if group2==1, absorb(quarter) robust cluster(gvkey)
# areg payouta largepe salgrowth logat da opprofit if group2==1, absorb(quarter) robust cluster(gvkey)
# Out:
#   [1]              "/home/kennesaw/Sunay/adofiles"
#   [2]  (BASE)      "/usr/local/sas/stata16/ado/base/"
#   [3]  (SITE)      "/usr/local/sas/ado/"
#   [4]              "."
#   [5]  (PERSONAL)  "~/ado/personal/"
#   [6]  (PLUS)      "~/ado/plus/"
#   [7]  (OLDPLACE)  "~/ado/"
# (144 observations deleted)
# (7 missing values generated)
# (786 observations deleted)
# Unknown #commandUnknown #commandUnknown #commandUnknown #commandUnknown #commandUnknown #commandUnknown #commandUnknown #commandUnknown #commandUnknown #commandUnknown #commandUnknown #commandUnknown #commandUnknown #commandUnknown #commandUnknown #commandUnknown #commandUnknown #command
# Linear regression, absorbing indicators         Number of obs     =      7,444
# Absorbed variable: quarter                      No. of categories =        142
#                                                 F(   5,    462)   =       2.57
#                                                 Prob > F          =     0.0261
# ...

# %% [raw]
# Going Public

# %%
# %%stata
# adopath++ "/home/kennesaw/Sunay/adofiles"
#
# use "/home/kennesaw/Sunay/Dividends/gopublic_q.dta", clear
#
# egen quarter=group(datacqtr)
#
# areg div2 private salgrowth logat da opprofit, absorb(quarter) robust cluster(gvkey)
# areg grossrepa private salgrowth logat da opprofit, absorb(quarter) robust cluster(gvkey)
# areg payouta private salgrowth logat da opprofit, absorb(quarter) robust cluster(gvkey)
# Out:
#   [1]              "/home/kennesaw/Sunay/adofiles"
#   [2]  (BASE)      "/usr/local/sas/stata16/ado/base/"
#   [3]  (SITE)      "/usr/local/sas/ado/"
#   [4]              "."
#   [5]  (PERSONAL)  "~/ado/personal/"
#   [6]  (PLUS)      "~/ado/plus/"
#   [7]  (OLDPLACE)  "~/ado/"
# (4 missing values generated)
#
# Linear regression, absorbing indicators         Number of obs     =     14,442
# Absorbed variable: quarter                      No. of categories =        143
#                                                 F(   5,    367)   =       2.50
#                                                 Prob > F          =     0.0305
#                                                 R-squared         =     0.0533
#                                                 Adj R-squared     =     0.0436
#                                                 Root MSE          =     0.0234
#
#                                 (Std. Err. adjusted for 368 clusters in gvkey)
# ...

# %% [raw]
# Going Private

# %%
# %%stata
# adopath++ "/home/kennesaw/Sunay/adofiles"
#
# use "/home/kennesaw/Sunay/Dividends/goprivate_q.dta", clear
#
# egen quarter=group(datacqtr)
#
# areg div2 private salgrowth logat da opprofit, absorb(quarter) robust cluster(gvkey)
# areg grossrepa private salgrowth logat da opprofit, absorb(quarter) robust cluster(gvkey)
# areg payouta private salgrowth logat da opprofit, absorb(quarter) robust cluster(gvkey)
#
# areg div2 private salgrowth logat da opprofit if pe1==1, absorb(quarter) robust cluster(gvkey)
# areg grossrepa private salgrowth logat da opprofit if pe1==1, absorb(quarter) robust cluster(gvkey)
# areg payouta private salgrowth logat da opprofit if pe1==1, absorb(quarter) robust cluster(gvkey)
# Out:
#   [1]              "/home/kennesaw/Sunay/adofiles"
#   [2]  (BASE)      "/usr/local/sas/stata16/ado/base/"
#   [3]  (SITE)      "/usr/local/sas/ado/"
#   [4]              "."
#   [5]  (PERSONAL)  "~/ado/personal/"
#   [6]  (PLUS)      "~/ado/plus/"
#   [7]  (OLDPLACE)  "~/ado/"
# (13 missing values generated)
#
# Linear regression, absorbing indicators         Number of obs     =     14,793
# Absorbed variable: quarter                      No. of categories =        144
#                                                 F(   5,    284)   =       2.84
#                                                 Prob > F          =     0.0161
#                                                 R-squared         =     0.0305
#                                                 Adj R-squared     =     0.0207
#                                                 Root MSE          =     0.0205
#
#                                 (Std. Err. adjusted for 285 clusters in gvkey)
# ...
