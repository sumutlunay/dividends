# %%
import ipystata
from ipystata.config import config_stata
config_stata('/usr/local/bin/stata')
# Out:
# IPyStata is loaded in batch mode.

# %% [markdown]
# *Annual PSM

# %%
# %%stata
# adopath++ "/home/kennesaw/Sunay/adofiles"
#
# use "/home/kennesaw/Sunay/Dividends/levelfull.dta", clear
#
# gen group1 = manag+employ
# gen group2 = pe1+pe2
#
# drop if (group1+group2==0)
#
# replace group1=0 if missing(group1)
# replace group2=0 if missing(group2)
#
# gen public=0
# replace public=1 if private==0
#
# logit private logat da int_cov loss intang ppe growth
# predict p
#
# egen gr=group(fyear ind3)
# gen ps = gr*10+p
#
# set seed 1984
# gen u=uniform()
# sort u
#
# psmatch2 private, pscore(ps) caliper(.1) noreplace neighbor(1)
# gen pair = _id if _treated==0
# replace pair = _n1 if _treated==1
# bysort pair: egen paircount = count(pair)
# drop if paircount !=2
#
# areg div2 private salgrowth logat da opprofit loss, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel replace
#
# gen in_sample=e(sample)
# total private if in_sample==1
# drop in_sample
#
# areg repurch2 private salgrowth logat da opprofit loss, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total private if in_sample==1
# drop in_sample
#
# areg payout2 private salgrowth logat da opprofit loss, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total private if in_sample==1
# drop in_sample
#
# /****/
# areg div1 private salgrowth logat da opprofit loss, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total private if in_sample==1
# drop in_sample
#
# areg repurch1 private salgrowth logat da opprofit loss, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total private if in_sample==1
# drop in_sample
#
# areg payout1 private salgrowth logat da opprofit loss, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total private if in_sample==1
# drop in_sample
# Out:
#   [1]              "/home/kennesaw/Sunay/adofiles"
#   [2]  (BASE)      "/usr/local/sas/stata16/ado/base/"
#   [3]  (SITE)      "/usr/local/sas/ado/"
#   [4]              "."
#   [5]  (PERSONAL)  "~/ado/personal/"
#   [6]  (PLUS)      "~/ado/plus/"
#   [7]  (OLDPLACE)  "~/ado/"
# (174,603 missing values generated)
# (174,603 missing values generated)
# (28 observations deleted)
# (174,603 real changes made)
# (174,603 real changes made)
# (174,603 real changes made)
#
# Iteration 0:   log likelihood = -9905.3497
# Iteration 1:   log likelihood = -9374.9096
# Iteration 2:   log likelihood = -9259.9697
# Iteration 3:   log likelihood = -9251.0091
# Iteration 4:   log likelihood = -9233.4773
# Iteration 5:   log likelihood = -9229.9549
# Iteration 6:   log likelihood = -9229.8556
# Iteration 7:   log likelihood = -9229.8553
#
# Logistic regression                             Number of obs     =    148,666
#                                                 LR chi2(7)        =    1350.99
#                                                 Prob > chi2       =     0.0000
# Log likelihood = -9229.8553                     Pseudo R2         =     0.0682
#
# ------------------------------------------------------------------------------
#      private |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#        logat |    .205994   .0101491    20.30   0.000     .1861022    .2258859
#           da |   .3230051   .0154944    20.85   0.000     .2926365    .3533736
#      int_cov |  -.0026216   .0006822    -3.84   0.000    -.0039587   -.0012846
#         loss |   .5237053   .0528321     9.91   0.000     .4201563    .6272543
#       intang |   2.130917   .0964732    22.09   0.000     1.941833    2.320001
#          ppe |   .0011257   .0063868     0.18   0.860    -.0113923    .0136437
#       growth |  -.0437207   .0137141    -3.19   0.001    -.0705999   -.0168415
#        _cons |  -6.379402   .0851605   -74.91   0.000    -6.546313    -6.21249
# ------------------------------------------------------------------------------
# Note: 325 failures and 0 successes completely determined.
# (option pr assumed; Pr(private))
# (28,008 missing values generated)
# (28,008 missing values generated)
# (29,847 missing values generated)
# (1,788 real changes made)
# (173,098 observations deleted)
#
# Linear regression, absorbing indicators         Number of obs     =      3,561
# Absorbed variable: fyear                        No. of categories =         35
#                                                 F(   6,   1471)   =      24.50
#                                                 Prob > F          =     0.0000
#                                                 R-squared         =     0.0690
#                                                 Adj R-squared     =     0.0585
#                                                 Root MSE          =     0.0238
#
#                               (Std. Err. adjusted for 1,472 clusters in gvkey)
# ------------------------------------------------------------------------------
#              |               Robust
#         div2 |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#      private |    -.00306   .0010535    -2.90   0.004    -.0051265   -.0009936
#    salgrowth |   -.000573   .0005703    -1.00   0.315    -.0016917    .0005457
#        logat |   .0011219   .0003016     3.72   0.000     .0005304    .0017135
#           da |   .0018639   .0008485     2.20   0.028     .0001995    .0035284
#     opprofit |   .0052318   .0022341     2.34   0.019     .0008495    .0096141
#         loss |  -.0074487   .0009989    -7.46   0.000     -.009408   -.0054894
#        _cons |   .0045338   .0020824     2.18   0.030      .000449    .0086186
# ------------------------------------------------------------------------------
# myfile.xml
# dir : seeout
#
# Total estimation                  Number of obs   =      3,561
#
# --------------------------------------------------------------
#              |      Total   Std. Err.     [95% Conf. Interval]
# -------------+------------------------------------------------
#      private |       1779   29.84124      1720.492    1837.508
# --------------------------------------------------------------
#
# Linear regression, absorbing indicators         Number of obs     =      3,576
# Absorbed variable: fyear                        No. of categories =         35
#                                                 F(   6,   1471)   =      15.31
#                                                 Prob > F          =     0.0000
#                                                 R-squared         =     0.0492
#                                                 Adj R-squared     =     0.0384
#                                                 Root MSE          =     0.0229
#
#                               (Std. Err. adjusted for 1,472 clusters in gvkey)
# ------------------------------------------------------------------------------
#              |               Robust
#     repurch2 |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#      private |   -.002853    .001369    -2.08   0.037    -.0055385   -.0001676
#    salgrowth |   .0031756   .0017213     1.84   0.065    -.0002008     .006552
#        logat |   .0008787   .0004718     1.86   0.063    -.0000467    .0018042
#           da |   .0006547   .0007314     0.90   0.371    -.0007801    .0020895
#     opprofit |   .0022349   .0014793     1.51   0.131    -.0006668    .0051366
#         loss |  -.0056782   .0012166    -4.67   0.000    -.0080646   -.0032918
#        _cons |    .003425   .0036543     0.94   0.349    -.0037432    .0105933
# ------------------------------------------------------------------------------
# myfile.xml
# dir : seeout
#
# Total estimation                  Number of obs   =      3,576
#
# --------------------------------------------------------------
#              |      Total   Std. Err.     [95% Conf. Interval]
# -------------+------------------------------------------------
#      private |       1788   29.90401      1729.369    1846.631
# --------------------------------------------------------------
#
# Linear regression, absorbing indicators         Number of obs     =      3,561
# Absorbed variable: fyear                        No. of categories =         35
#                                                 F(   6,   1471)   =      26.26
#                                                 Prob > F          =     0.0000
#                                                 R-squared         =     0.0671
#                                                 Adj R-squared     =     0.0565
#                                                 Root MSE          =     0.0404
#
#                               (Std. Err. adjusted for 1,472 clusters in gvkey)
# ------------------------------------------------------------------------------
#              |               Robust
#      payout2 |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#      private |  -.0048396   .0020175    -2.40   0.017     -.008797   -.0008822
#    salgrowth |   .0038477   .0029048     1.32   0.186    -.0018502    .0095456
#        logat |   .0017081   .0007019     2.43   0.015     .0003313    .0030849
#           da |    .003878    .001649     2.35   0.019     .0006433    .0071127
#     opprofit |   .0112233    .004125     2.72   0.007     .0031318    .0193148
#         loss |  -.0140884   .0020359    -6.92   0.000     -.018082   -.0100948
#        _cons |   .0094905   .0052312     1.81   0.070     -.000771    .0197521
# ------------------------------------------------------------------------------
# myfile.xml
# dir : seeout
#
# Total estimation                  Number of obs   =      3,561
#
# --------------------------------------------------------------
#              |      Total   Std. Err.     [95% Conf. Interval]
# -------------+------------------------------------------------
#      private |       1779   29.84124      1720.492    1837.508
# --------------------------------------------------------------
# . areg div1 private salgrowth logat da opprofit loss, absorb(fyear) robust cluster(gvkey)
#
# Linear regression, absorbing indicators         Number of obs     =      3,560
# Absorbed variable: fyear                        No. of categories =         35
#                                                 F(   6,   1470)   =      31.99
#                                                 Prob > F          =     0.0000
#                                                 R-squared         =     0.0648
#                                                 Adj R-squared     =     0.0541
#                                                 Root MSE          =     0.1494
#
#                               (Std. Err. adjusted for 1,471 clusters in gvkey)
# ------------------------------------------------------------------------------
#              |               Robust
#         div1 |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#      private |  -.0192769   .0071085    -2.71   0.007    -.0332208   -.0053329
#    salgrowth |  -.0071264   .0034927    -2.04   0.041    -.0139775   -.0002752
#        logat |   .0100193   .0019111     5.24   0.000     .0062705    .0137681
#           da |     .00369   .0054836     0.67   0.501    -.0070666    .0144465
#     opprofit |   .0080735   .0137866     0.59   0.558      -.01897     .035117
#         loss |  -.0355137   .0070377    -5.05   0.000    -.0493187   -.0217086
#        _cons |   .0185061   .0124949     1.48   0.139    -.0060038    .0430159
# ------------------------------------------------------------------------------
# myfile.xml
# dir : seeout
#
# Total estimation                  Number of obs   =      3,560
#
# --------------------------------------------------------------
#              |      Total   Std. Err.     [95% Conf. Interval]
# -------------+------------------------------------------------
#      private |       1779   29.83705      1720.501    1837.499
# --------------------------------------------------------------
#
# Linear regression, absorbing indicators         Number of obs     =      3,575
# Absorbed variable: fyear                        No. of categories =         35
#                                                 F(   6,   1470)   =      17.01
#                                                 Prob > F          =     0.0000
#                                                 R-squared         =     0.0351
#                                                 Adj R-squared     =     0.0242
#                                                 Root MSE          =     0.1591
#
#                               (Std. Err. adjusted for 1,471 clusters in gvkey)
# ------------------------------------------------------------------------------
#              |               Robust
#     repurch1 |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#      private |  -.0155848   .0084667    -1.84   0.066    -.0321929    .0010234
#    salgrowth |    .002531   .0079842     0.32   0.751    -.0131306    .0181927
#        logat |   .0060538   .0026164     2.31   0.021     .0009215    .0111861
#           da |  -.0039502   .0044862    -0.88   0.379    -.0127503    .0048498
#     opprofit |  -.0046438   .0089596    -0.52   0.604    -.0222188    .0129313
#         loss |  -.0300284   .0076736    -3.91   0.000    -.0450807   -.0149761
#        _cons |   .0275662   .0198821     1.39   0.166    -.0114341    .0665664
# ------------------------------------------------------------------------------
# myfile.xml
# dir : seeout
#
# Total estimation                  Number of obs   =      3,575
#
# --------------------------------------------------------------
#              |      Total   Std. Err.     [95% Conf. Interval]
# -------------+------------------------------------------------
#      private |       1788   29.89983      1729.378    1846.622
# --------------------------------------------------------------
#
# Linear regression, absorbing indicators         Number of obs     =      3,560
# Absorbed variable: fyear                        No. of categories =         35
#                                                 F(   6,   1470)   =      34.48
#                                                 Prob > F          =     0.0000
#                                                 R-squared         =     0.0540
#                                                 Adj R-squared     =     0.0433
#                                                 Root MSE          =     0.2727
#
#                               (Std. Err. adjusted for 1,471 clusters in gvkey)
# ------------------------------------------------------------------------------
#              |               Robust
#      payout1 |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#      private |  -.0283692   .0120151    -2.36   0.018    -.0519378   -.0048005
#    salgrowth |  -.0013092   .0143474    -0.09   0.927    -.0294529    .0268344
#        logat |    .016903   .0036089     4.68   0.000      .009824    .0239821
#           da |   .0078237   .0083051     0.94   0.346    -.0084674    .0241147
#     opprofit |   .0173373   .0191983     0.90   0.367    -.0203218    .0549964
#         loss |  -.0715197   .0121165    -5.90   0.000    -.0952873   -.0477522
#        _cons |   .0392051    .025812     1.52   0.129    -.0114272    .0898374
# ------------------------------------------------------------------------------
# myfile.xml
# dir : seeout
#
# Total estimation                  Number of obs   =      3,560
#
# --------------------------------------------------------------
#              |      Total   Std. Err.     [95% Conf. Interval]
# -------------+------------------------------------------------
#      private |       1779   29.83705      1720.501    1837.499
# --------------------------------------------------------------

# %% [markdown]
# *Annual PSM with Private Dummy Broken Down

# %%
# %%stata
# adopath++ "/home/kennesaw/Sunay/adofiles"
#
# use "/home/kennesaw/Sunay/Dividends/levelfull.dta", clear
#
# gen group1 = manag+employ
# gen group2 = pe1+pe2
#
# drop if (group1+group2==0)
#
# replace group1=0 if missing(group1)
# replace group2=0 if missing(group2)
#
# gen public=0
# replace public=1 if private==0
#
# replace manag=0 if missing(manag)
# replace employ=0 if missing(employ)
# replace pe1=0 if missing(pe1)
# replace pe2=0 if missing(pe2)
#
# logit private logat da int_cov loss intang ppe growth
# predict p
#
# egen gr=group(fyear ind3)
# gen ps = gr*10+p
#
# set seed 1984
# gen u=uniform()
# sort u
#
# psmatch2 private, pscore(ps) caliper(.1) noreplace neighbor(1)
# gen pair = _id if _treated==0
# replace pair = _n1 if _treated==1
# bysort pair: egen paircount = count(pair)
# drop if paircount !=2
#
# local controls salgrowth logat da opprofit loss
#
# areg div2 pe1 pe2 manag employ `controls', absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel replace
#
# gen in_sample=e(sample)
# total  pe1 pe2 manag employ if in_sample==1
# drop in_sample
#
# test pe1=pe2
# test pe1=manag
# test pe1=employ
# test pe2=manag
# test pe2=employ
# test manag=employ
#
# areg repurch2 pe1 pe2 manag employ `controls', absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total  pe1 pe2 manag employ if in_sample==1
# drop in_sample
#
# test pe1=pe2
# test pe1=manag
# test pe1=employ
# test pe2=manag
# test pe2=employ
# test manag=employ
#
# areg payout2 pe1 pe2 manag employ `controls', absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total  pe1 pe2 manag employ if in_sample==1
# drop in_sample
#
# test pe1=pe2
# test pe1=manag
# test pe1=employ
# test pe2=manag
# test pe2=employ
# test manag=employ
#
# /******/
# areg div1 pe1 pe2 manag employ `controls', absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total  pe1 pe2 manag employ if in_sample==1
# drop in_sample
#
# test pe1=pe2
# test pe1=manag
# test pe1=employ
# test pe2=manag
# test pe2=employ
# test manag=employ
#
# areg repurch1 pe1 pe2 manag employ `controls', absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total  pe1 pe2 manag employ if in_sample==1
# drop in_sample
#
# test pe1=pe2
# test pe1=manag
# test pe1=employ
# test pe2=manag
# test pe2=employ
# test manag=employ
#
# areg payout1 pe1 pe2 manag employ `controls', absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total  pe1 pe2 manag employ if in_sample==1
# drop in_sample
#
# test pe1=pe2
# test pe1=manag
# test pe1=employ
# test pe2=manag
# test pe2=employ
# test manag=employ
# Out:
#   [1]              "/home/kennesaw/Sunay/adofiles"
#   [2]  (BASE)      "/usr/local/sas/stata16/ado/base/"
#   [3]  (SITE)      "/usr/local/sas/ado/"
#   [4]              "."
#   [5]  (PERSONAL)  "~/ado/personal/"
#   [6]  (PLUS)      "~/ado/plus/"
#   [7]  (OLDPLACE)  "~/ado/"
# (174,603 missing values generated)
# (174,603 missing values generated)
# (28 observations deleted)
# (174,603 real changes made)
# (174,603 real changes made)
# (174,603 real changes made)
# (174,603 real changes made)
# (174,603 real changes made)
# (174,603 real changes made)
# (174,603 real changes made)
#
# Iteration 0:   log likelihood = -9905.3497
# Iteration 1:   log likelihood = -9374.9096
# Iteration 2:   log likelihood = -9259.9697
# Iteration 3:   log likelihood = -9251.0091
# Iteration 4:   log likelihood = -9233.4773
# Iteration 5:   log likelihood = -9229.9549
# Iteration 6:   log likelihood = -9229.8556
# Iteration 7:   log likelihood = -9229.8553
#
# Logistic regression                             Number of obs     =    148,666
#                                                 LR chi2(7)        =    1350.99
#                                                 Prob > chi2       =     0.0000
# Log likelihood = -9229.8553                     Pseudo R2         =     0.0682
#
# ------------------------------------------------------------------------------
#      private |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#        logat |    .205994   .0101491    20.30   0.000     .1861022    .2258859
#           da |   .3230051   .0154944    20.85   0.000     .2926365    .3533736
#      int_cov |  -.0026216   .0006822    -3.84   0.000    -.0039587   -.0012846
#         loss |   .5237053   .0528321     9.91   0.000     .4201563    .6272543
#       intang |   2.130917   .0964732    22.09   0.000     1.941833    2.320001
#          ppe |   .0011257   .0063868     0.18   0.860    -.0113923    .0136437
#       growth |  -.0437207   .0137141    -3.19   0.001    -.0705999   -.0168415
#        _cons |  -6.379402   .0851605   -74.91   0.000    -6.546313    -6.21249
# ------------------------------------------------------------------------------
# Note: 325 failures and 0 successes completely determined.
# (option pr assumed; Pr(private))
# (28,008 missing values generated)
# (28,008 missing values generated)
# (29,847 missing values generated)
# (1,788 real changes made)
# (173,098 observations deleted)
#
# Linear regression, absorbing indicators         Number of obs     =      3,561
# Absorbed variable: fyear                        No. of categories =         35
#                                                 F(   9,   1471)   =      16.97
#                                                 Prob > F          =     0.0000
#                                                 R-squared         =     0.0711
#                                                 Adj R-squared     =     0.0598
#                                                 Root MSE          =     0.0238
#
#                               (Std. Err. adjusted for 1,472 clusters in gvkey)
# ------------------------------------------------------------------------------
#              |               Robust
#         div2 |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          pe1 |  -.0041476   .0011928    -3.48   0.001    -.0064874   -.0018079
#          pe2 |  -.0045384   .0018782    -2.42   0.016    -.0082227   -.0008542
#        manag |  -.0004527   .0020636    -0.22   0.826    -.0045006    .0035951
#       employ |  -.0029675   .0036009    -0.82   0.410    -.0100311     .004096
#    salgrowth |  -.0005217   .0005716    -0.91   0.362     -.001643    .0005997
#        logat |   .0011831   .0002929     4.04   0.000     .0006085    .0017577
#           da |   .0020089   .0008759     2.29   0.022     .0002907    .0037271
#     opprofit |   .0054597   .0022568     2.42   0.016     .0010328    .0098865
#         loss |  -.0070567   .0009613    -7.34   0.000    -.0089425    -.005171
#        _cons |   .0038547    .002105     1.83   0.067    -.0002745    .0079838
# ------------------------------------------------------------------------------
# myfile.xml
# dir : seeout
#
# Total estimation                  Number of obs   =      3,561
#
# --------------------------------------------------------------
#              |      Total   Std. Err.     [95% Conf. Interval]
# -------------+------------------------------------------------
#          pe1 |       1023    27.0059      970.0514    1075.949
#          pe2 |        148   11.91171      124.6455    171.3545
#        manag |        462   20.05427       422.681     501.319
#       employ |        146   11.83441      122.7971    169.2029
# --------------------------------------------------------------
#
#  ( 1)  pe1 - pe2 = 0
#
#        F(  1,  3560) =  800.64
#             Prob > F =    0.0000
#
#  ( 1)  pe1 - manag = 0
#
#        F(  1,  3560) =  225.28
#             Prob > F =    0.0000
#
#  ( 1)  pe1 - employ = 0
#
#        F(  1,  3560) =  806.82
#             Prob > F =    0.0000
#
#  ( 1)  pe2 - manag = 0
#
#        F(  1,  3560) =  169.27
#             Prob > F =    0.0000
#
#  ( 1)  pe2 - employ = 0
#
#        F(  1,  3560) =    0.01
#             Prob > F =    0.9072
#
#  ( 1)  manag - employ = 0
#
#        F(  1,  3560) =  172.13
#             Prob > F =    0.0000
#
# Linear regression, absorbing indicators         Number of obs     =      3,576
# Absorbed variable: fyear                        No. of categories =         35
#                                                 F(   9,   1471)   =      10.28
#                                                 Prob > F          =     0.0000
#                                                 R-squared         =     0.0841
#                                                 Adj R-squared     =     0.0730
#                                                 Root MSE          =     0.0225
#
#                               (Std. Err. adjusted for 1,472 clusters in gvkey)
# ------------------------------------------------------------------------------
#              |               Robust
#     repurch2 |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          pe1 |  -.0056272   .0008267    -6.81   0.000    -.0072489   -.0040055
#          pe2 |  -.0041799     .00167    -2.50   0.012    -.0074557   -.0009041
#        manag |  -.0040407   .0012191    -3.31   0.001     -.006432   -.0016494
#       employ |   .0177433   .0113671     1.56   0.119    -.0045541    .0400408
#    salgrowth |   .0031986   .0017042     1.88   0.061    -.0001443    .0065415
#        logat |   .0008711   .0004253     2.05   0.041     .0000368    .0017053
#           da |   .0013573   .0005373     2.53   0.012     .0003033    .0024114
#     opprofit |   .0038019   .0015778     2.41   0.016      .000707    .0068968
#         loss |  -.0046691   .0008744    -5.34   0.000    -.0063844   -.0029538
#        _cons |   .0024391   .0029658     0.82   0.411    -.0033786    .0082567
# ------------------------------------------------------------------------------
# myfile.xml
# dir : seeout
#
# Total estimation                  Number of obs   =      3,576
#
# --------------------------------------------------------------
#              |      Total   Std. Err.     [95% Conf. Interval]
# -------------+------------------------------------------------
#          pe1 |       1030   27.08381      976.8987    1083.101
#          pe2 |        148   11.91278      124.6435    171.3565
#        manag |        464   20.09744      424.5964    503.4036
#       employ |        146   11.83547      122.7951    169.2049
# --------------------------------------------------------------
#
#  ( 1)  pe1 - pe2 = 0
#
#        F(  1,  3575) =  809.72
#             Prob > F =    0.0000
#
#  ( 1)  pe1 - manag = 0
#
#        F(  1,  3575) =  228.04
#             Prob > F =    0.0000
#
#  ( 1)  pe1 - employ = 0
#
#        F(  1,  3575) =  815.94
#             Prob > F =    0.0000
#
#  ( 1)  pe2 - manag = 0
#
#        F(  1,  3575) =  170.92
#             Prob > F =    0.0000
#
#  ( 1)  pe2 - employ = 0
#
#        F(  1,  3575) =    0.01
#             Prob > F =    0.9072
#
#  ( 1)  manag - employ = 0
#
#        F(  1,  3575) =  173.79
#             Prob > F =    0.0000
#
# Linear regression, absorbing indicators         Number of obs     =      3,561
# Absorbed variable: fyear                        No. of categories =         35
#                                                 F(   9,   1471)   =      18.31
#                                                 Prob > F          =     0.0000
#                                                 R-squared         =     0.0823
#                                                 Adj R-squared     =     0.0711
#                                                 Root MSE          =     0.0401
#
#                               (Std. Err. adjusted for 1,472 clusters in gvkey)
# ------------------------------------------------------------------------------
#              |               Robust
#      payout2 |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          pe1 |  -.0088716   .0018064    -4.91   0.000     -.012415   -.0053282
#          pe2 |  -.0088875   .0030144    -2.95   0.003    -.0148005   -.0029746
#        manag |  -.0036858   .0031613    -1.17   0.244    -.0098869    .0025154
#       employ |   .0184223    .013635     1.35   0.177    -.0083238    .0451685
#    salgrowth |   .0039015   .0028861     1.35   0.177    -.0017598    .0095628
#        logat |   .0017531   .0006376     2.75   0.006     .0005023    .0030039
#           da |   .0048223   .0016413     2.94   0.003     .0016028    .0080418
#     opprofit |   .0132356    .004396     3.01   0.003     .0046124    .0218588
#         loss |  -.0125665   .0017021    -7.38   0.000    -.0159054   -.0092276
#        _cons |   .0077498   .0044415     1.74   0.081    -.0009625    .0164622
# ------------------------------------------------------------------------------
# myfile.xml
# dir : seeout
#
# Total estimation                  Number of obs   =      3,561
#
# --------------------------------------------------------------
#              |      Total   Std. Err.     [95% Conf. Interval]
# -------------+------------------------------------------------
#          pe1 |       1023    27.0059      970.0514    1075.949
#          pe2 |        148   11.91171      124.6455    171.3545
#        manag |        462   20.05427       422.681     501.319
#       employ |        146   11.83441      122.7971    169.2029
# --------------------------------------------------------------
#
#  ( 1)  pe1 - pe2 = 0
#
#        F(  1,  3560) =  800.64
#             Prob > F =    0.0000
#
#  ( 1)  pe1 - manag = 0
#
#        F(  1,  3560) =  225.28
#             Prob > F =    0.0000
#
#  ( 1)  pe1 - employ = 0
#
#        F(  1,  3560) =  806.82
#             Prob > F =    0.0000
#
#  ( 1)  pe2 - manag = 0
#
#        F(  1,  3560) =  169.27
#             Prob > F =    0.0000
#
#  ( 1)  pe2 - employ = 0
#
#        F(  1,  3560) =    0.01
#             Prob > F =    0.9072
#
#  ( 1)  manag - employ = 0
#
#        F(  1,  3560) =  172.13
#             Prob > F =    0.0000
# . areg div1 pe1 pe2 manag employ `controls', absorb(fyear) robust cluster(gvkey)
#
# Linear regression, absorbing indicators         Number of obs     =      3,560
# Absorbed variable: fyear                        No. of categories =         35
#                                                 F(   9,   1470)   =      21.74
#                                                 Prob > F          =     0.0000
#                                                 R-squared         =     0.0669
#                                                 Adj R-squared     =     0.0555
#                                                 Root MSE          =     0.1493
#
#                               (Std. Err. adjusted for 1,471 clusters in gvkey)
# ------------------------------------------------------------------------------
#              |               Robust
#         div1 |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          pe1 |  -.0247574   .0080015    -3.09   0.002     -.040453   -.0090618
#          pe2 |  -.0380735   .0105593    -3.61   0.000    -.0587864   -.0173606
#        manag |  -.0041876   .0141433    -0.30   0.767    -.0319308    .0235556
#       employ |  -.0152742   .0274117    -0.56   0.577    -.0690445    .0384961
#    salgrowth |  -.0067635   .0035121    -1.93   0.054    -.0136527    .0001257
#        logat |   .0103477   .0018429     5.61   0.000     .0067327    .0139626
#           da |   .0047508    .005632     0.84   0.399    -.0062968    .0157984
#     opprofit |   .0098546   .0137995     0.71   0.475    -.0172142    .0369234
#         loss |  -.0329597   .0065159    -5.06   0.000    -.0457412   -.0201781
#        _cons |   .0144225   .0123967     1.16   0.245    -.0098947    .0387397
# ------------------------------------------------------------------------------
# myfile.xml
# dir : seeout
#
# Total estimation                  Number of obs   =      3,560
#
# --------------------------------------------------------------
#              |      Total   Std. Err.     [95% Conf. Interval]
# -------------+------------------------------------------------
#          pe1 |       1023   27.00437      970.0544    1075.946
#          pe2 |        148   11.91163      124.6457    171.3543
#        manag |        462   20.05385      422.6818    501.3182
#       employ |        146   11.83434      122.7972    169.2028
# --------------------------------------------------------------
#
#  ( 1)  pe1 - pe2 = 0
#
#        F(  1,  3559) =  800.69
#             Prob > F =    0.0000
#
#  ( 1)  pe1 - manag = 0
#
#        F(  1,  3559) =  225.29
#             Prob > F =    0.0000
#
#  ( 1)  pe1 - employ = 0
#
#        F(  1,  3559) =  806.87
#             Prob > F =    0.0000
#
#  ( 1)  pe2 - manag = 0
#
#        F(  1,  3559) =  169.27
#             Prob > F =    0.0000
#
#  ( 1)  pe2 - employ = 0
#
#        F(  1,  3559) =    0.01
#             Prob > F =    0.9072
#
#  ( 1)  manag - employ = 0
#
#        F(  1,  3559) =  172.13
#             Prob > F =    0.0000
#
# Linear regression, absorbing indicators         Number of obs     =      3,575
# Absorbed variable: fyear                        No. of categories =         35
#                                                 F(   9,   1470)   =      11.40
#                                                 Prob > F          =     0.0000
#                                                 R-squared         =     0.0698
#                                                 Adj R-squared     =     0.0584
#                                                 Root MSE          =     0.1563
#
#                               (Std. Err. adjusted for 1,471 clusters in gvkey)
# ------------------------------------------------------------------------------
#              |               Robust
#     repurch1 |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          pe1 |  -.0340984    .005706    -5.98   0.000    -.0452912   -.0229057
#          pe2 |  -.0234945   .0130956    -1.79   0.073    -.0491826    .0021936
#        manag |  -.0252849   .0084325    -3.00   0.003     -.041826   -.0087438
#       employ |   .1261273   .0630054     2.00   0.045     .0025373    .2497173
#    salgrowth |   .0026525   .0080469     0.33   0.742    -.0131321    .0184372
#        logat |    .005966   .0023143     2.58   0.010     .0014264    .0105056
#           da |    .000797   .0033326     0.24   0.811    -.0057401    .0073341
#     opprofit |    .006003   .0082342     0.73   0.466    -.0101489     .022155
#         loss |  -.0233091   .0059508    -3.92   0.000    -.0349821   -.0116361
#        _cons |   .0211768   .0162999     1.30   0.194    -.0107967    .0531503
# ------------------------------------------------------------------------------
# myfile.xml
# dir : seeout
#
# Total estimation                  Number of obs   =      3,575
#
# --------------------------------------------------------------
#              |      Total   Std. Err.     [95% Conf. Interval]
# -------------+------------------------------------------------
#          pe1 |       1030   27.08228      976.9017    1083.098
#          pe2 |        148   11.91271      124.6436    171.3564
#        manag |        464   20.09702      424.5972    503.4028
#       employ |        146    11.8354      122.7952    169.2048
# --------------------------------------------------------------
#
#  ( 1)  pe1 - pe2 = 0
#
#        F(  1,  3574) =  809.77
#             Prob > F =    0.0000
#
#  ( 1)  pe1 - manag = 0
#
#        F(  1,  3574) =  228.05
#             Prob > F =    0.0000
#
#  ( 1)  pe1 - employ = 0
#
#        F(  1,  3574) =  815.99
#             Prob > F =    0.0000
#
#  ( 1)  pe2 - manag = 0
#
#        F(  1,  3574) =  170.92
#             Prob > F =    0.0000
#
#  ( 1)  pe2 - employ = 0
#
#        F(  1,  3574) =    0.01
#             Prob > F =    0.9072
#
#  ( 1)  manag - employ = 0
#
#        F(  1,  3574) =  173.79
#             Prob > F =    0.0000
#
# Linear regression, absorbing indicators         Number of obs     =      3,560
# Absorbed variable: fyear                        No. of categories =         35
#                                                 F(   9,   1470)   =      24.12
#                                                 Prob > F          =     0.0000
#                                                 R-squared         =     0.0670
#                                                 Adj R-squared     =     0.0556
#                                                 Root MSE          =     0.2709
#
#                               (Std. Err. adjusted for 1,471 clusters in gvkey)
# ------------------------------------------------------------------------------
#              |               Robust
#      payout1 |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          pe1 |  -.0484858   .0125124    -3.88   0.000    -.0730299   -.0239416
#          pe2 |  -.0637308   .0182976    -3.48   0.001    -.0996229   -.0278387
#        manag |  -.0293377     .01888    -1.55   0.120    -.0663722    .0076968
#       employ |   .1187865   .0518219     2.29   0.022     .0171338    .2204392
#    salgrowth |  -.0010401   .0144373    -0.07   0.943    -.0293599    .0272797
#        logat |   .0169516   .0033202     5.11   0.000     .0104388    .0234645
#           da |    .013482   .0081347     1.66   0.098    -.0024749    .0294388
#     opprofit |   .0296311   .0196026     1.51   0.131    -.0088209    .0680831
#         loss |   -.062991    .010983    -5.74   0.000     -.084535    -.041447
#        _cons |    .030421   .0229166     1.33   0.185    -.0145316    .0753737
# ------------------------------------------------------------------------------
# myfile.xml
# dir : seeout
#
# Total estimation                  Number of obs   =      3,560
#
# --------------------------------------------------------------
#              |      Total   Std. Err.     [95% Conf. Interval]
# -------------+------------------------------------------------
#          pe1 |       1023   27.00437      970.0544    1075.946
#          pe2 |        148   11.91163      124.6457    171.3543
#        manag |        462   20.05385      422.6818    501.3182
#       employ |        146   11.83434      122.7972    169.2028
# --------------------------------------------------------------
#
#  ( 1)  pe1 - pe2 = 0
#
#        F(  1,  3559) =  800.69
#             Prob > F =    0.0000
#
#  ( 1)  pe1 - manag = 0
#
#        F(  1,  3559) =  225.29
#             Prob > F =    0.0000
#
#  ( 1)  pe1 - employ = 0
#
#        F(  1,  3559) =  806.87
#             Prob > F =    0.0000
#
#  ( 1)  pe2 - manag = 0
#
#        F(  1,  3559) =  169.27
#             Prob > F =    0.0000
#
#  ( 1)  pe2 - employ = 0
#
#        F(  1,  3559) =    0.01
#             Prob > F =    0.9072
#
#  ( 1)  manag - employ = 0
#
#        F(  1,  3559) =  172.13
#             Prob > F =    0.0000
#
# .

# %% [markdown]
# *Quarterly PSM

# %%
# %%stata
# adopath++ "/home/kennesaw/Sunay/adofiles"
#
# use "/home/kennesaw/Sunay/Dividends/levelfull_q.dta", clear
#
# gen group1 = manag+employ
# gen group2 = pe1+pe2
#
# drop if (group1+group2==0)
#
# replace group1=0 if missing(group1)
# replace group2=0 if missing(group2)
#
# gen public=0
# replace public=1 if private==0
#
# replace manag=0 if missing(manag)
# replace employ=0 if missing(employ)
# replace pe1=0 if missing(pe1)
# replace pe2=0 if missing(pe2)
#
# /***Interest Coverage give problem in logit, I take the log here****/
# gen intcov = log(int_cov)
#
# logit private logat da intcov loss intang ppe growth
# predict p
#
# egen gr=group(datacqtr FFI48)
# gen ps = gr*10+p
#
# set seed 1984
# gen u=uniform()
# sort u
#
# psmatch2 private, pscore(ps) caliper(.1) noreplace neighbor(1)
# gen pair = _id if _treated==0
# replace pair = _n1 if _treated==1
# bysort pair: egen paircount = count(pair)
# drop if paircount !=2
#
# egen quarter=group(datacqtr)
# local controls salgrowth logat da opprofit loss
#
# areg div2 private `controls', absorb(quarter) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel replace
#
# gen in_sample=e(sample)
# total private if in_sample==1
# drop in_sample
#
# areg netrepa private `controls', absorb(quarter) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total private if in_sample==1
# drop in_sample
#
# areg payouta private `controls', absorb(quarter) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total private if in_sample==1
# drop in_sample
#
# /*********/
#
# areg div1 private `controls', absorb(quarter) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total private if in_sample==1
# drop in_sample
#
# areg netrepi private `controls', absorb(quarter) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total private if in_sample==1
# drop in_sample
#
# areg payouti private `controls', absorb(quarter) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total private if in_sample==1
# drop in_sample
# Out:
#   [1]              "/home/kennesaw/Sunay/adofiles"
#   [2]  (BASE)      "/usr/local/sas/stata16/ado/base/"
#   [3]  (SITE)      "/usr/local/sas/ado/"
#   [4]              "."
#   [5]  (PERSONAL)  "~/ado/personal/"
#   [6]  (PLUS)      "~/ado/plus/"
#   [7]  (OLDPLACE)  "~/ado/"
# (717,278 missing values generated)
# (717,278 missing values generated)
# (144 observations deleted)
# (717,278 real changes made)
# (717,278 real changes made)
# (717,278 real changes made)
# (717,278 real changes made)
# (717,278 real changes made)
# (717,278 real changes made)
# (717,278 real changes made)
# . gen intcov = log(int_cov)
# (293,971 missing values generated)
#
# Iteration 0:   log likelihood = -45972.247
# Iteration 1:   log likelihood = -41736.488
# Iteration 2:   log likelihood = -39835.894
# Iteration 3:   log likelihood =  -39714.81
# Iteration 4:   log likelihood = -39714.735
# Iteration 5:   log likelihood = -39714.735
#
# Logistic regression                             Number of obs     =    426,658
#                                                 LR chi2(7)        =   12515.02
#                                                 Prob > chi2       =     0.0000
# Log likelihood = -39714.735                     Pseudo R2         =     0.1361
#
# ------------------------------------------------------------------------------
#      private |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#        logat |   .1646826   .0050903    32.35   0.000     .1547057    .1746595
#           da |   .8016687   .0176883    45.32   0.000     .7670001    .8363372
#       intcov |  -.5730728   .0092363   -62.05   0.000    -.5911757   -.5549699
#         loss |   .1626124   .0265903     6.12   0.000     .1104963    .2147284
#       intang |   1.185837   .0500188    23.71   0.000     1.087802    1.283872
#          ppe |  -.5294618   .0427229   -12.39   0.000    -.6131972   -.4457264
#       growth |  -.0417558   .0309338    -1.35   0.177    -.1023849    .0188733
#        _cons |  -4.653336    .042655  -109.09   0.000    -4.736938   -4.569733
# ------------------------------------------------------------------------------
# (option pr assumed; Pr(private))
# (301,416 missing values generated)
# (3,299 missing values generated)
# (303,087 missing values generated)
# (312,668 missing values generated)
# (9,156 real changes made)
# (709,762 observations deleted)
#
# Linear regression, absorbing indicators         Number of obs     =     18,312
# Absorbed variable: quarter                      No. of categories =        142
#                                                 F(   6,   4006)   =      20.51
#                                                 Prob > F          =     0.0000
#                                                 R-squared         =     0.0585
#                                                 Adj R-squared     =     0.0509
#                                                 Root MSE          =     0.0143
#
#                               (Std. Err. adjusted for 4,007 clusters in gvkey)
# ------------------------------------------------------------------------------
#              |               Robust
#         div2 |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#      private |  -.0012808   .0004592    -2.79   0.005    -.0021811   -.0003805
#    salgrowth |   .0016136   .0005082     3.18   0.002     .0006173    .0026099
#        logat |   .0005089   .0001148     4.43   0.000     .0002838    .0007339
#           da |  -.0019041   .0007009    -2.72   0.007    -.0032782   -.0005299
#     opprofit |   .1057682   .0212897     4.97   0.000     .0640285    .1475078
#         loss |   -.000339   .0003414    -0.99   0.321    -.0010083    .0003303
#        _cons |   .0001692    .001045     0.16   0.871    -.0018796     .002218
# ------------------------------------------------------------------------------
# myfile.xml
# dir : seeout
#
# Total estimation                  Number of obs   =     18,312
#
# --------------------------------------------------------------
#              |      Total   Std. Err.     [95% Conf. Interval]
# -------------+------------------------------------------------
#      private |       9156   67.66277      9023.375    9288.625
# --------------------------------------------------------------
#
# Linear regression, absorbing indicators         Number of obs     =     18,312
# Absorbed variable: quarter                      No. of categories =        142
#                                                 F(   6,   4006)   =      17.27
#                                                 Prob > F          =     0.0000
#                                                 R-squared         =     0.0301
#                                                 Adj R-squared     =     0.0223
#                                                 Root MSE          =     0.0041
#
#                               (Std. Err. adjusted for 4,007 clusters in gvkey)
# ------------------------------------------------------------------------------
#              |               Robust
#      netrepa |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#      private |  -.0005531   .0001719    -3.22   0.001    -.0008901   -.0002161
#    salgrowth |   .0003912   .0001909     2.05   0.041     .0000169    .0007655
#        logat |   -.000019   .0000837    -0.23   0.820     -.000183     .000145
#           da |  -.0008408   .0005855    -1.44   0.151    -.0019887    .0003071
#     opprofit |   .0193965   .0094957     2.04   0.041     .0007796    .0380135
#         loss |  -.0001829   .0000726    -2.52   0.012    -.0003253   -.0000405
#        _cons |    .001186   .0007694     1.54   0.123    -.0003223    .0026944
# ------------------------------------------------------------------------------
# myfile.xml
# dir : seeout
#
# Total estimation                  Number of obs   =     18,312
#
# --------------------------------------------------------------
#              |      Total   Std. Err.     [95% Conf. Interval]
# -------------+------------------------------------------------
#      private |       9156   67.66277      9023.375    9288.625
# --------------------------------------------------------------
#
# Linear regression, absorbing indicators         Number of obs     =     18,312
# Absorbed variable: quarter                      No. of categories =        142
#                                                 F(   6,   4006)   =      25.29
#                                                 Prob > F          =     0.0000
#                                                 R-squared         =     0.0642
#                                                 Adj R-squared     =     0.0566
#                                                 Root MSE          =     0.0177
#
#                               (Std. Err. adjusted for 4,007 clusters in gvkey)
# ------------------------------------------------------------------------------
#              |               Robust
#      payouta |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#      private |  -.0020761   .0005633    -3.69   0.000    -.0031805   -.0009716
#    salgrowth |   .0026458   .0006527     4.05   0.000     .0013661    .0039255
#        logat |   .0004851   .0001671     2.90   0.004     .0001576    .0008127
#           da |  -.0028941   .0010804    -2.68   0.007    -.0050122    -.000776
#     opprofit |   .1573271   .0296615     5.30   0.000     .0991739    .2154802
#         loss |  -.0003968   .0004127    -0.96   0.336    -.0012059    .0004123
#        _cons |   .0010647   .0015565     0.68   0.494     -.001987    .0041163
# ------------------------------------------------------------------------------
# myfile.xml
# dir : seeout
#
# Total estimation                  Number of obs   =     18,312
#
# --------------------------------------------------------------
#              |      Total   Std. Err.     [95% Conf. Interval]
# -------------+------------------------------------------------
#      private |       9156   67.66277      9023.375    9288.625
# --------------------------------------------------------------
# . areg div1 private `controls', absorb(quarter) robust cluster(gvkey)
#
# Linear regression, absorbing indicators         Number of obs     =     18,312
# Absorbed variable: quarter                      No. of categories =        142
#                                                 F(   6,   4006)   =      18.24
#                                                 Prob > F          =     0.0000
#                                                 R-squared         =     0.0427
#                                                 Adj R-squared     =     0.0350
#                                                 Root MSE          =     0.4938
#
#                               (Std. Err. adjusted for 4,007 clusters in gvkey)
# ------------------------------------------------------------------------------
#              |               Robust
#         div1 |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#      private |  -.0685754   .0146452    -4.68   0.000    -.0972881   -.0398626
#    salgrowth |   .0526556   .0211031     2.50   0.013     .0112818    .0940294
#        logat |   .0179621   .0033679     5.33   0.000     .0113592     .024565
#           da |  -.0629051   .0152117    -4.14   0.000    -.0927285   -.0330817
#     opprofit |  -.4014491   .5748553    -0.70   0.485    -1.528485    .7255871
#         loss |    .001696   .0120171     0.14   0.888    -.0218642    .0252562
#        _cons |   .1509622   .0307771     4.91   0.000     .0906221    .2113024
# ------------------------------------------------------------------------------
# myfile.xml
# dir : seeout
#
# Total estimation                  Number of obs   =     18,312
#
# --------------------------------------------------------------
#              |      Total   Std. Err.     [95% Conf. Interval]
# -------------+------------------------------------------------
#      private |       9156   67.66277      9023.375    9288.625
# --------------------------------------------------------------
#
# Linear regression, absorbing indicators         Number of obs     =     18,312
# Absorbed variable: quarter                      No. of categories =        142
#                                                 F(   6,   4006)   =      23.46
#                                                 Prob > F          =     0.0000
#                                                 R-squared         =     0.0243
#                                                 Adj R-squared     =     0.0164
#                                                 Root MSE          =     0.1194
#
#                               (Std. Err. adjusted for 4,007 clusters in gvkey)
# ------------------------------------------------------------------------------
#              |               Robust
#      netrepi |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#      private |  -.0201277   .0035008    -5.75   0.000    -.0269912   -.0132641
#    salgrowth |   .0108574    .005022     2.16   0.031     .0010115    .0207033
#        logat |  -.0007784   .0016244    -0.48   0.632     -.003963    .0024062
#           da |  -.0203597   .0105397    -1.93   0.053    -.0410234     .000304
#     opprofit |   .1130461   .1660498     0.68   0.496    -.2125038     .438596
#         loss |   -.006211   .0021968    -2.83   0.005     -.010518    -.001904
#        _cons |   .0513937    .014958     3.44   0.001     .0220678    .0807196
# ------------------------------------------------------------------------------
# myfile.xml
# dir : seeout
#
# Total estimation                  Number of obs   =     18,312
#
# --------------------------------------------------------------
#              |      Total   Std. Err.     [95% Conf. Interval]
# -------------+------------------------------------------------
#      private |       9156   67.66277      9023.375    9288.625
# --------------------------------------------------------------
#
# Linear regression, absorbing indicators         Number of obs     =     18,312
# Absorbed variable: quarter                      No. of categories =        142
#                                                 F(   6,   4006)   =      19.97
#                                                 Prob > F          =     0.0000
#                                                 R-squared         =     0.0398
#                                                 Adj R-squared     =     0.0320
#                                                 Root MSE          =     0.6248
#
#                               (Std. Err. adjusted for 4,007 clusters in gvkey)
# ------------------------------------------------------------------------------
#              |               Robust
#      payouti |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#      private |  -.1048785   .0169911    -6.17   0.000    -.1381905   -.0715665
#    salgrowth |   .0765168   .0271491     2.82   0.005     .0232895    .1297441
#        logat |   .0145921   .0043164     3.38   0.001     .0061295    .0230547
#           da |  -.0859434   .0211157    -4.07   0.000    -.1273418   -.0445449
#     opprofit |  -.5237976   .6362465    -0.82   0.410    -1.771195    .7235995
#         loss |  -.0028533   .0140234    -0.20   0.839    -.0303469    .0246403
#        _cons |   .2594447   .0406332     6.39   0.000      .179781    .3391085
# ------------------------------------------------------------------------------
# myfile.xml
# dir : seeout
#
# Total estimation                  Number of obs   =     18,312
#
# --------------------------------------------------------------
#              |      Total   Std. Err.     [95% Conf. Interval]
# -------------+------------------------------------------------
#      private |       9156   67.66277      9023.375    9288.625
# --------------------------------------------------------------

# %% [markdown]
# *Quarterly PSM with Private Dummy Broken Down

# %%
# %%stata
# adopath++ "/home/kennesaw/Sunay/adofiles"
#
# use "/home/kennesaw/Sunay/Dividends/levelfull_q.dta", clear
#
# gen group1 = manag+employ
# gen group2 = pe1+pe2
#
# drop if (group1+group2==0)
#
# replace group1=0 if missing(group1)
# replace group2=0 if missing(group2)
#
# gen public=0
# replace public=1 if private==0
#
# replace manag=0 if missing(manag)
# replace employ=0 if missing(employ)
# replace pe1=0 if missing(pe1)
# replace pe2=0 if missing(pe2)
#
# /***Interest Coverage give problem in logit, I take the log here****/
# gen intcov = log(int_cov)
#
# logit private logat da intcov loss intang ppe growth
# predict p
#
# egen gr=group(datacqtr ind3)
# gen ps = gr*10+p
#
# set seed 1984
# gen u=uniform()
# sort u
#
# psmatch2 private, pscore(ps) caliper(.1) noreplace neighbor(1)
# gen pair = _id if _treated==0
# replace pair = _n1 if _treated==1
# bysort pair: egen paircount = count(pair)
# drop if paircount !=2
#
# egen quarter=group(datacqtr)
# local controls salgrowth logat da opprofit loss
#
# areg div2 pe1 pe2 manag employ `controls', absorb(quarter) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel replace
#
# gen in_sample=e(sample)
# total  pe1 pe2 manag employ if in_sample==1
# drop in_sample
#
# test pe1=pe2
# test pe1=manag
# test pe1=employ
# test pe2=manag
# test pe2=employ
# test manag=employ
#
# areg netrepa pe1 pe2 manag employ `controls', absorb(quarter) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total  pe1 pe2 manag employ if in_sample==1
# drop in_sample
#
# test pe1=pe2
# test pe1=manag
# test pe1=employ
# test pe2=manag
# test pe2=employ
# test manag=employ
#
# areg payouta pe1 pe2 manag employ `controls', absorb(quarter) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total  pe1 pe2 manag employ if in_sample==1
# drop in_sample
#
# test pe1=pe2
# test pe1=manag
# test pe1=employ
# test pe2=manag
# test pe2=employ
# test manag=employ
#
# /*********/
#
# areg div1 pe1 pe2 manag employ `controls', absorb(quarter) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total  pe1 pe2 manag employ if in_sample==1
# drop in_sample
#
# test pe1=pe2
# test pe1=manag
# test pe1=employ
# test pe2=manag
# test pe2=employ
# test manag=employ
#
# areg netrepi pe1 pe2 manag employ `controls', absorb(quarter) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total  pe1 pe2 manag employ if in_sample==1
# drop in_sample
#
# test pe1=pe2
# test pe1=manag
# test pe1=employ
# test pe2=manag
# test pe2=employ
# test manag=employ
#
# areg payouti pe1 pe2 manag employ `controls', absorb(quarter) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# gen in_sample=e(sample)
# total  pe1 pe2 manag employ if in_sample==1
# drop in_sample
#
# test pe1=pe2
# test pe1=manag
# test pe1=employ
# test pe2=manag
# test pe2=employ
# test manag=employ
# Out:
#   [1]              "/home/kennesaw/Sunay/adofiles"
#   [2]  (BASE)      "/usr/local/sas/stata16/ado/base/"
#   [3]  (SITE)      "/usr/local/sas/ado/"
#   [4]              "."
#   [5]  (PERSONAL)  "~/ado/personal/"
#   [6]  (PLUS)      "~/ado/plus/"
#   [7]  (OLDPLACE)  "~/ado/"
# (717,278 missing values generated)
# (717,278 missing values generated)
# (144 observations deleted)
# (717,278 real changes made)
# (717,278 real changes made)
# (717,278 real changes made)
# (717,278 real changes made)
# (717,278 real changes made)
# (717,278 real changes made)
# (717,278 real changes made)
# . gen intcov = log(int_cov)
# (293,971 missing values generated)
#
# Iteration 0:   log likelihood = -45972.247
# Iteration 1:   log likelihood = -41736.488
# Iteration 2:   log likelihood = -39835.894
# Iteration 3:   log likelihood =  -39714.81
# Iteration 4:   log likelihood = -39714.735
# Iteration 5:   log likelihood = -39714.735
#
# Logistic regression                             Number of obs     =    426,658
#                                                 LR chi2(7)        =   12515.02
#                                                 Prob > chi2       =     0.0000
# Log likelihood = -39714.735                     Pseudo R2         =     0.1361
#
# ------------------------------------------------------------------------------
#      private |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#        logat |   .1646826   .0050903    32.35   0.000     .1547057    .1746595
#           da |   .8016687   .0176883    45.32   0.000     .7670001    .8363372
#       intcov |  -.5730728   .0092363   -62.05   0.000    -.5911757   -.5549699
#         loss |   .1626124   .0265903     6.12   0.000     .1104963    .2147284
#       intang |   1.185837   .0500188    23.71   0.000     1.087802    1.283872
#          ppe |  -.5294618   .0427229   -12.39   0.000    -.6131972   -.4457264
#       growth |  -.0417558   .0309338    -1.35   0.177    -.1023849    .0188733
#        _cons |  -4.653336    .042655  -109.09   0.000    -4.736938   -4.569733
# ------------------------------------------------------------------------------
# (option pr assumed; Pr(private))
# (301,416 missing values generated)
# (744 missing values generated)
# (301,524 missing values generated)
# (311,135 missing values generated)
# (8,942 real changes made)
# (710,190 observations deleted)
#
# Linear regression, absorbing indicators         Number of obs     =     17,884
# Absorbed variable: quarter                      No. of categories =        141
#                                                 F(   9,   3222)   =      17.70
#                                                 Prob > F          =     0.0000
#                                                 R-squared         =     0.0670
#                                                 Adj R-squared     =     0.0591
#                                                 Root MSE          =     0.0135
#
#                               (Std. Err. adjusted for 3,223 clusters in gvkey)
# ------------------------------------------------------------------------------
#              |               Robust
#         div2 |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          pe1 |   -.001664   .0005067    -3.28   0.001    -.0026574   -.0006705
#          pe2 |  -.0019837    .000897    -2.21   0.027    -.0037424    -.000225
#        manag |   .0012904   .0010482     1.23   0.218    -.0007648    .0033456
#       employ |   .0001227   .0019317     0.06   0.949    -.0036647    .0039101
#    salgrowth |   .0011817   .0004695     2.52   0.012     .0002611    .0021022
#        logat |   .0007067    .000108     6.55   0.000      .000495    .0009184
#           da |  -.0016155   .0007532    -2.14   0.032    -.0030922   -.0001388
#     opprofit |   .0915933   .0199046     4.60   0.000     .0525663    .1306203
#         loss |   -.000658   .0003222    -2.04   0.041    -.0012898   -.0000262
#        _cons |  -.0010971   .0011171    -0.98   0.326    -.0032874    .0010931
# ------------------------------------------------------------------------------
# myfile.xml
# dir : seeout
#
# Total estimation                  Number of obs   =     17,884
#
# --------------------------------------------------------------
#              |      Total   Std. Err.     [95% Conf. Interval]
# -------------+------------------------------------------------
#          pe1 |       5422   61.46862      5301.516    5542.484
#          pe2 |        768     27.112      714.8579    821.1421
#        manag |       2128   43.30007      2043.128    2212.872
#       employ |        624   24.54101      575.8972    672.1028
# --------------------------------------------------------------
#
#  ( 1)  pe1 - pe2 = 0
#
#        F(  1, 17883) = 4350.08
#             Prob > F =    0.0000
#
#  ( 1)  pe1 - manag = 0
#
#        F(  1, 17883) = 1562.64
#             Prob > F =    0.0000
#
#  ( 1)  pe1 - employ = 0
#
#        F(  1, 17883) = 4837.28
#             Prob > F =    0.0000
#
#  ( 1)  pe2 - manag = 0
#
#        F(  1, 17883) =  662.29
#             Prob > F =    0.0000
#
#  ( 1)  pe2 - employ = 0
#
#        F(  1, 17883) =   14.91
#             Prob > F =    0.0001
#
#  ( 1)  manag - employ = 0
#
#        F(  1, 17883) =  861.50
#             Prob > F =    0.0000
#
# Linear regression, absorbing indicators         Number of obs     =     17,884
# Absorbed variable: quarter                      No. of categories =        141
#                                                 F(   9,   3222)   =      12.25
#                                                 Prob > F          =     0.0000
#                                                 R-squared         =     0.0439
#                                                 Adj R-squared     =     0.0359
#                                                 Root MSE          =     0.0042
#
#                               (Std. Err. adjusted for 3,223 clusters in gvkey)
# ------------------------------------------------------------------------------
#              |               Robust
#      netrepa |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          pe1 |  -.0007692   .0000983    -7.83   0.000    -.0009619   -.0005765
#          pe2 |  -.0006107   .0001254    -4.87   0.000    -.0008567   -.0003648
#        manag |  -.0007124   .0001231    -5.78   0.000    -.0009538   -.0004709
#       employ |   .0022306   .0025144     0.89   0.375    -.0026993    .0071606
#    salgrowth |   .0005077   .0002361     2.15   0.032     .0000447    .0009708
#        logat |   .0000738    .000092     0.80   0.422    -.0001066    .0002542
#           da |  -.0009039   .0005174    -1.75   0.081    -.0019184    .0001106
#     opprofit |   .0200239    .009611     2.08   0.037     .0011797    .0388681
#         loss |   .0000308    .000132     0.23   0.816     -.000228    .0002896
#        _cons |   .0005224   .0006555     0.80   0.426    -.0007628    .0018075
# ------------------------------------------------------------------------------
# myfile.xml
# dir : seeout
#
# Total estimation                  Number of obs   =     17,884
#
# --------------------------------------------------------------
#              |      Total   Std. Err.     [95% Conf. Interval]
# -------------+------------------------------------------------
#          pe1 |       5422   61.46862      5301.516    5542.484
#          pe2 |        768     27.112      714.8579    821.1421
#        manag |       2128   43.30007      2043.128    2212.872
#       employ |        624   24.54101      575.8972    672.1028
# --------------------------------------------------------------
#
#  ( 1)  pe1 - pe2 = 0
#
#        F(  1, 17883) = 4350.08
#             Prob > F =    0.0000
#
#  ( 1)  pe1 - manag = 0
#
#        F(  1, 17883) = 1562.64
#             Prob > F =    0.0000
#
#  ( 1)  pe1 - employ = 0
#
#        F(  1, 17883) = 4837.28
#             Prob > F =    0.0000
#
#  ( 1)  pe2 - manag = 0
#
#        F(  1, 17883) =  662.29
#             Prob > F =    0.0000
#
#  ( 1)  pe2 - employ = 0
#
#        F(  1, 17883) =   14.91
#             Prob > F =    0.0001
#
#  ( 1)  manag - employ = 0
#
#        F(  1, 17883) =  861.50
#             Prob > F =    0.0000
#
# Linear regression, absorbing indicators         Number of obs     =     17,884
# Absorbed variable: quarter                      No. of categories =        141
#                                                 F(   9,   3222)   =      20.06
#                                                 Prob > F          =     0.0000
#                                                 R-squared         =     0.0704
#                                                 Adj R-squared     =     0.0625
#                                                 Root MSE          =     0.0170
#
#                               (Std. Err. adjusted for 3,223 clusters in gvkey)
# ------------------------------------------------------------------------------
#              |               Robust
#      payouta |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          pe1 |  -.0025635   .0006058    -4.23   0.000    -.0037513   -.0013757
#          pe2 |  -.0027332    .001093    -2.50   0.012    -.0048764   -.0005901
#        manag |   .0005963   .0012399     0.48   0.631    -.0018348    .0030275
#       employ |   .0035482   .0036872     0.96   0.336    -.0036813    .0107778
#    salgrowth |   .0025093   .0006693     3.75   0.000      .001197    .0038216
#        logat |   .0007575   .0001607     4.71   0.000     .0004425    .0010725
#           da |  -.0026561   .0010474    -2.54   0.011    -.0047098   -.0006025
#     opprofit |   .1375207   .0283712     4.85   0.000     .0818932    .1931482
#         loss |  -.0004715    .000416    -1.13   0.257    -.0012871    .0003441
#        _cons |  -.0007694   .0015245    -0.50   0.614    -.0037585    .0022197
# ------------------------------------------------------------------------------
# myfile.xml
# dir : seeout
#
# Total estimation                  Number of obs   =     17,884
#
# --------------------------------------------------------------
#              |      Total   Std. Err.     [95% Conf. Interval]
# -------------+------------------------------------------------
#          pe1 |       5422   61.46862      5301.516    5542.484
#          pe2 |        768     27.112      714.8579    821.1421
#        manag |       2128   43.30007      2043.128    2212.872
#       employ |        624   24.54101      575.8972    672.1028
# --------------------------------------------------------------
#
#  ( 1)  pe1 - pe2 = 0
#
#        F(  1, 17883) = 4350.08
#             Prob > F =    0.0000
#
#  ( 1)  pe1 - manag = 0
#
#        F(  1, 17883) = 1562.64
#             Prob > F =    0.0000
#
#  ( 1)  pe1 - employ = 0
#
#        F(  1, 17883) = 4837.28
#             Prob > F =    0.0000
#
#  ( 1)  pe2 - manag = 0
#
#        F(  1, 17883) =  662.29
#             Prob > F =    0.0000
#
#  ( 1)  pe2 - employ = 0
#
#        F(  1, 17883) =   14.91
#             Prob > F =    0.0001
#
#  ( 1)  manag - employ = 0
#
#        F(  1, 17883) =  861.50
#             Prob > F =    0.0000
# . areg div1 pe1 pe2 manag employ `controls', absorb(quarter) robust cluster(gvkey)
#
# Linear regression, absorbing indicators         Number of obs     =     17,884
# Absorbed variable: quarter                      No. of categories =        141
#                                                 F(   9,   3222)   =      12.48
#                                                 Prob > F          =     0.0000
#                                                 R-squared         =     0.0502
#                                                 Adj R-squared     =     0.0422
#                                                 Root MSE          =     0.4484
#
#                               (Std. Err. adjusted for 3,223 clusters in gvkey)
# ------------------------------------------------------------------------------
#              |               Robust
#         div1 |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          pe1 |  -.0743311   .0148772    -5.00   0.000    -.1035009   -.0451613
#          pe2 |  -.0811283   .0242242    -3.35   0.001    -.1286247   -.0336318
#        manag |   .0164928   .0297111     0.56   0.579    -.0417617    .0747474
#       employ |  -.0157506   .0719494    -0.22   0.827    -.1568219    .1253207
#    salgrowth |   .0248224    .018288     1.36   0.175    -.0110348    .0606796
#        logat |    .019101   .0034786     5.49   0.000     .0122806    .0259214
#           da |  -.0567995    .016624    -3.42   0.001    -.0893942   -.0242047
#     opprofit |  -.4216751   .5644378    -0.75   0.455    -1.528369    .6850185
#         loss |  -.0110191   .0106084    -1.04   0.299     -.031819    .0097808
#        _cons |   .1243535   .0332956     3.73   0.000     .0590707    .1896363
# ------------------------------------------------------------------------------
# myfile.xml
# dir : seeout
#
# Total estimation                  Number of obs   =     17,884
#
# --------------------------------------------------------------
#              |      Total   Std. Err.     [95% Conf. Interval]
# -------------+------------------------------------------------
#          pe1 |       5422   61.46862      5301.516    5542.484
#          pe2 |        768     27.112      714.8579    821.1421
#        manag |       2128   43.30007      2043.128    2212.872
#       employ |        624   24.54101      575.8972    672.1028
# --------------------------------------------------------------
#
#  ( 1)  pe1 - pe2 = 0
#
#        F(  1, 17883) = 4350.08
#             Prob > F =    0.0000
#
#  ( 1)  pe1 - manag = 0
#
#        F(  1, 17883) = 1562.64
#             Prob > F =    0.0000
#
#  ( 1)  pe1 - employ = 0
#
#        F(  1, 17883) = 4837.28
#             Prob > F =    0.0000
#
#  ( 1)  pe2 - manag = 0
#
#        F(  1, 17883) =  662.29
#             Prob > F =    0.0000
#
#  ( 1)  pe2 - employ = 0
#
#        F(  1, 17883) =   14.91
#             Prob > F =    0.0001
#
#  ( 1)  manag - employ = 0
#
#        F(  1, 17883) =  861.50
#             Prob > F =    0.0000
#
# Linear regression, absorbing indicators         Number of obs     =     17,884
# Absorbed variable: quarter                      No. of categories =        141
#                                                 F(   9,   3222)   =      17.09
#                                                 Prob > F          =     0.0000
#                                                 R-squared         =     0.0360
#                                                 Adj R-squared     =     0.0279
#                                                 Root MSE          =     0.1183
#
#                               (Std. Err. adjusted for 3,223 clusters in gvkey)
# ------------------------------------------------------------------------------
#              |               Robust
#      netrepi |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          pe1 |  -.0244557   .0023745   -10.30   0.000    -.0291114   -.0198001
#          pe2 |  -.0192996   .0028942    -6.67   0.000    -.0249743   -.0136249
#        manag |  -.0229424   .0027235    -8.42   0.000    -.0282823   -.0176025
#       employ |   .0374534    .047127     0.79   0.427    -.0549486    .1298554
#    salgrowth |   .0131178   .0057248     2.29   0.022     .0018931    .0243425
#        logat |   .0021085   .0017977     1.17   0.241    -.0014163    .0056332
#           da |  -.0202243   .0092246    -2.19   0.028    -.0383109   -.0021377
#     opprofit |   .1919072    .169063     1.14   0.256    -.1395748    .5233891
#         loss |   .0020741   .0028274     0.73   0.463    -.0034696    .0076177
#        _cons |   .0254111    .012894     1.97   0.049     .0001299    .0506924
# ------------------------------------------------------------------------------
# myfile.xml
# dir : seeout
#
# Total estimation                  Number of obs   =     17,884
#
# --------------------------------------------------------------
#              |      Total   Std. Err.     [95% Conf. Interval]
# -------------+------------------------------------------------
#          pe1 |       5422   61.46862      5301.516    5542.484
#          pe2 |        768     27.112      714.8579    821.1421
#        manag |       2128   43.30007      2043.128    2212.872
#       employ |        624   24.54101      575.8972    672.1028
# --------------------------------------------------------------
#
#  ( 1)  pe1 - pe2 = 0
#
#        F(  1, 17883) = 4350.08
#             Prob > F =    0.0000
#
#  ( 1)  pe1 - manag = 0
#
#        F(  1, 17883) = 1562.64
#             Prob > F =    0.0000
#
#  ( 1)  pe1 - employ = 0
#
#        F(  1, 17883) = 4837.28
#             Prob > F =    0.0000
#
#  ( 1)  pe2 - manag = 0
#
#        F(  1, 17883) =  662.29
#             Prob > F =    0.0000
#
#  ( 1)  pe2 - employ = 0
#
#        F(  1, 17883) =   14.91
#             Prob > F =    0.0001
#
#  ( 1)  manag - employ = 0
#
#        F(  1, 17883) =  861.50
#             Prob > F =    0.0000
#
# Linear regression, absorbing indicators         Number of obs     =     17,884
# Absorbed variable: quarter                      No. of categories =        141
#                                                 F(   9,   3222)   =      13.26
#                                                 Prob > F          =     0.0000
#                                                 R-squared         =     0.0452
#                                                 Adj R-squared     =     0.0372
#                                                 Root MSE          =     0.5625
#
#                               (Std. Err. adjusted for 3,223 clusters in gvkey)
# ------------------------------------------------------------------------------
#              |               Robust
#      payouti |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          pe1 |  -.1061698   .0176235    -6.02   0.000    -.1407242   -.0716153
#          pe2 |  -.1113773   .0286084    -3.89   0.000    -.1674698   -.0552849
#        manag |  -.0131295   .0327302    -0.40   0.688    -.0773037    .0510446
#       employ |   .0234692   .0776887     0.30   0.763    -.1288551    .1757935
#    salgrowth |   .0390204   .0225337     1.73   0.083    -.0051614    .0832022
#        logat |   .0196217   .0043857     4.47   0.000     .0110227    .0282207
#           da |  -.0797987   .0214655    -3.72   0.000    -.1218862   -.0377112
#     opprofit |  -.3433037   .6166497    -0.56   0.578    -1.552369    .8657617
#         loss |  -.0012379   .0123464    -0.10   0.920    -.0254455    .0229697
#        _cons |   .1841754   .0404703     4.55   0.000     .1048253    .2635255
# ------------------------------------------------------------------------------
# myfile.xml
# dir : seeout
#
# Total estimation                  Number of obs   =     17,884
#
# --------------------------------------------------------------
#              |      Total   Std. Err.     [95% Conf. Interval]
# -------------+------------------------------------------------
#          pe1 |       5422   61.46862      5301.516    5542.484
#          pe2 |        768     27.112      714.8579    821.1421
#        manag |       2128   43.30007      2043.128    2212.872
#       employ |        624   24.54101      575.8972    672.1028
# --------------------------------------------------------------
#
#  ( 1)  pe1 - pe2 = 0
#
#        F(  1, 17883) = 4350.08
#             Prob > F =    0.0000
#
#  ( 1)  pe1 - manag = 0
#
#        F(  1, 17883) = 1562.64
#             Prob > F =    0.0000
#
#  ( 1)  pe1 - employ = 0
#
#        F(  1, 17883) = 4837.28
#             Prob > F =    0.0000
#
#  ( 1)  pe2 - manag = 0
#
#        F(  1, 17883) =  662.29
#             Prob > F =    0.0000
#
#  ( 1)  pe2 - employ = 0
#
#        F(  1, 17883) =   14.91
#             Prob > F =    0.0001
#
#  ( 1)  manag - employ = 0
#
#        F(  1, 17883) =  861.50
#             Prob > F =    0.0000
