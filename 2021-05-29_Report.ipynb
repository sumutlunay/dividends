# %%
import ipystata
from ipystata.config import config_stata
config_stata('/usr/local/bin/stata')
# Out:
# IPyStata is loaded in batch mode.

# %% [markdown]
# /*Explore for management ownership within private groups*/

# %% [markdown]
# Annual Results

# %%
# %%stata
# adopath++ "/home/kennesaw/Sunay/adofiles"
#
# use "/home/kennesaw/Sunay/Dividends/withinprivates.dta", clear
#
# areg div2 c.manag##c.Mgmt_own salgrowth logat da opprofit loss, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel replace
# areg repurch2 c.manag##c.Mgmt_own salgrowth logat da opprofit loss, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
# areg payout2 c.manag##c.Mgmt_own salgrowth logat da opprofit loss, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
#
# areg div2 c.employ##c.Mgmt_own salgrowth logat da opprofit loss, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
# areg repurch2 c.employ##c.Mgmt_own salgrowth logat da opprofit loss, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
# areg payout2 c.employ##c.Mgmt_own salgrowth logat da opprofit loss, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
#
# areg div2 c.pe1##c.Mgmt_own salgrowth logat da opprofit loss, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
# areg repurch2 c.pe1##c.Mgmt_own salgrowth logat da opprofit loss, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
# areg payout2 c.pe1##c.Mgmt_own salgrowth logat da opprofit loss, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
#
# areg div2 c.pe2##c.Mgmt_own salgrowth logat da opprofit loss, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
# areg repurch2 c.pe2##c.Mgmt_own salgrowth logat da opprofit loss, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
# areg payout2 c.pe2##c.Mgmt_own salgrowth logat da opprofit loss, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
# Out:
#   [1]              "/home/kennesaw/Sunay/adofiles"
#   [2]  (BASE)      "/usr/local/sas/stata16/ado/base/"
#   [3]  (SITE)      "/usr/local/sas/ado/"
#   [4]              "."
#   [5]  (PERSONAL)  "~/ado/personal/"
#   [6]  (PLUS)      "~/ado/plus/"
#   [7]  (OLDPLACE)  "~/ado/"
#
# Linear regression, absorbing indicators         Number of obs     =      2,160
# Absorbed variable: fyear                        No. of categories =         42
#                                                 F(   8,    470)   =       2.66
#                                                 Prob > F          =     0.0073
#                                                 R-squared         =     0.1570
#                                                 Adj R-squared     =     0.1374
#                                                 Root MSE          =     0.0429
#
#                                       (Std. Err. adjusted for 471 clusters in gvkey)
# ...

# %%
Quarterly Results

# %%
# %%stata
# adopath++ "/home/kennesaw/Sunay/adofiles"
#
# use "/home/kennesaw/Sunay/Dividends/withinprivates_q.dta", clear
#
# egen quarter=group(datacqtr)
#
# areg div2 c.manag##c.Mgmt_own salgrowth logat da opprofit loss, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel replace
# areg netrepa c.manag##c.Mgmt_own salgrowth logat da opprofit loss, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
# areg payouta c.manag##c.Mgmt_own salgrowth logat da opprofit loss, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
#
# areg div2 c.employ##c.Mgmt_own salgrowth logat da opprofit loss, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
# areg netrepa c.employ##c.Mgmt_own salgrowth logat da opprofit loss, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
# areg payouta c.employ##c.Mgmt_own salgrowth logat da opprofit loss, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
#
# areg div2 c.pe1##c.Mgmt_own salgrowth logat da opprofit loss, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
# areg netrepa c.pe1##c.Mgmt_own salgrowth logat da opprofit loss, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
# areg payouta c.pe1##c.Mgmt_own salgrowth logat da opprofit loss, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
#
# areg div2 c.pe2##c.Mgmt_own salgrowth logat da opprofit loss, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
# areg netrepa c.pe2##c.Mgmt_own salgrowth logat da opprofit loss, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
# areg payouta c.pe2##c.Mgmt_own salgrowth logat da opprofit loss, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
# Out:
#   [1]              "/home/kennesaw/Sunay/adofiles"
#   [2]  (BASE)      "/usr/local/sas/stata16/ado/base/"
#   [3]  (SITE)      "/usr/local/sas/ado/"
#   [4]              "."
#   [5]  (PERSONAL)  "~/ado/personal/"
#   [6]  (PLUS)      "~/ado/plus/"
#   [7]  (OLDPLACE)  "~/ado/"
# (7 missing values generated)
#
# Linear regression, absorbing indicators         Number of obs     =     11,035
# Absorbed variable: fyear                        No. of categories =         39
#                                                 F(   8,    610)   =       3.02
#                                                 Prob > F          =     0.0025
#                                                 R-squared         =     0.0595
#                                                 Adj R-squared     =     0.0556
#                                                 Root MSE          =     0.0283
#
#                                       (Std. Err. adjusted for 611 clusters in gvkey)
# ...

# %% [raw]
# Dividend change models

# %% [raw]
# Annual

# %%
# %%stata
# adopath++ "/home/kennesaw/Sunay/adofiles"
#
# use "/home/kennesaw/Sunay/Dividends/withinprivates.dta", clear
#
# areg chgdps Mgmt_own lagdps eps, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel replace
# areg chgdps c.manag##c.Mgmt_own lagdps eps, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
# areg chgdps c.employ##c.Mgmt_own lagdps eps, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
# areg chgdps c.pe1##c.Mgmt_own lagdps eps, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
# areg chgdps c.pe2##c.Mgmt_own lagdps eps, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# areg chgpayoutps Mgmt_own lagpayoutps eps, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
# areg chgpayoutps c.manag##c.Mgmt_own lagpayoutps eps, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
# areg chgpayoutps c.employ##c.Mgmt_own lagpayoutps eps, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
# areg chgpayoutps c.pe1##c.Mgmt_own lagpayoutps eps, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
# areg chgpayoutps c.pe2##c.Mgmt_own lagpayoutps eps, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
# Out:
#   [1]              "/home/kennesaw/Sunay/adofiles"
#   [2]  (BASE)      "/usr/local/sas/stata16/ado/base/"
#   [3]  (SITE)      "/usr/local/sas/ado/"
#   [4]              "."
#   [5]  (PERSONAL)  "~/ado/personal/"
#   [6]  (PLUS)      "~/ado/plus/"
#   [7]  (OLDPLACE)  "~/ado/"
#
# Linear regression, absorbing indicators         Number of obs     =        864
# Absorbed variable: fyear                        No. of categories =         42
#                                                 F(   3,    195)   =     131.02
#                                                 Prob > F          =     0.0000
#                                                 R-squared         =     0.3974
#                                                 Adj R-squared     =     0.3650
#                                                 Root MSE          = 28514.0744
#
#                                 (Std. Err. adjusted for 196 clusters in gvkey)
# ...

# %% [raw]
# Quarterly

# %%
# %%stata
# adopath++ "/home/kennesaw/Sunay/adofiles"
#
# use "/home/kennesaw/Sunay/Dividends/withinprivates_q.dta", clear
#
# areg chgdps Mgmt_own lagdps eps, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel replace
# areg chgdps c.manag##c.Mgmt_own lagdps eps, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
# areg chgdps c.employ##c.Mgmt_own lagdps eps, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
# areg chgdps c.pe1##c.Mgmt_own lagdps eps, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
# areg chgdps c.pe2##c.Mgmt_own lagdps eps, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# areg chgpayoutps Mgmt_own lagpayoutps eps, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
# areg chgpayoutps c.manag##c.Mgmt_own lagpayoutps eps, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
# areg chgpayoutps c.employ##c.Mgmt_own lagpayoutps eps, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
# areg chgpayoutps c.pe1##c.Mgmt_own lagpayoutps eps, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
# areg chgpayoutps c.pe2##c.Mgmt_own lagpayoutps eps, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
# Out:
#   [1]              "/home/kennesaw/Sunay/adofiles"
#   [2]  (BASE)      "/usr/local/sas/stata16/ado/base/"
#   [3]  (SITE)      "/usr/local/sas/ado/"
#   [4]              "."
#   [5]  (PERSONAL)  "~/ado/personal/"
#   [6]  (PLUS)      "~/ado/plus/"
#   [7]  (OLDPLACE)  "~/ado/"
#
# Linear regression, absorbing indicators         Number of obs     =      7,943
# Absorbed variable: fyear                        No. of categories =         38
#                                                 F(   3,    483)   =       3.35
#                                                 Prob > F          =     0.0189
#                                                 R-squared         =     0.1852
#                                                 Adj R-squared     =     0.1811
#                                                 Root MSE          = 13009.9429
#
#                                 (Std. Err. adjusted for 484 clusters in gvkey)
# ...

# %%
# %%stata
# adopath++ "/home/kennesaw/Sunay/adofiles"
#
# use "/home/kennesaw/Sunay/Dividends/withinprivates.dta", clear
#
# areg chgdps lagdps eps if manag==1, absorb(fyear) robust cluster(gvkey)
# areg chgdps lagdps eps if pe1==1, absorb(fyear) robust cluster(gvkey)
# areg chgdps lagdps eps if pe2==1, absorb(fyear) robust cluster(gvkey)
#
# areg chgdps chgeps if manag==1, absorb(fyear) robust cluster(gvkey)
# areg chgdps chgeps if pe1==1, absorb(fyear) robust cluster(gvkey)
# areg chgdps chgeps if pe2==1, absorb(fyear) robust cluster(gvkey)
# Out:
#   [1]              "/home/kennesaw/Sunay/adofiles"
#   [2]  (BASE)      "/usr/local/sas/stata16/ado/base/"
#   [3]  (SITE)      "/usr/local/sas/ado/"
#   [4]              "."
#   [5]  (PERSONAL)  "~/ado/personal/"
#   [6]  (PLUS)      "~/ado/plus/"
#   [7]  (OLDPLACE)  "~/ado/"
#
# Linear regression, absorbing indicators         Number of obs     =        248
# Absorbed variable: fyear                        No. of categories =         35
#                                                 F(   2,     50)   =   7.40e+08
#                                                 Prob > F          =     0.0000
#                                                 R-squared         =     0.9997
#                                                 Adj R-squared     =     0.9997
#                                                 Root MSE          =    89.0479
#
#                                  (Std. Err. adjusted for 51 clusters in gvkey)
# ...
