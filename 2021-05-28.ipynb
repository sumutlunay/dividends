# %%
import ipystata
from ipystata.config import config_stata
config_stata('/usr/local/bin/stata')
# Out:
# IPyStata is loaded in batch mode.

# %% [markdown]
# Annual Results

# %% [markdown]
# /*Explore for management ownership within private groups*/

# %%
# %%stata
# adopath++ "/home/kennesaw/Sunay/adofiles"
#
# use "/home/kennesaw/Sunay/Dividends/withinprivates.dta", clear
#
# gen group1 = manag+employ
# gen group2 = pe1+pe2
#
# # drop if employ==1
# drop if (group1+group2==0)
#
# sum mgmt_ownership Mgmt_own
#
# areg div2 manag salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# areg div2 c.manag##c.Mgmt_own salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
#
#
# areg repurch2 manag salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# areg repurch2 c.manag##c.Mgmt_own salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
#
#
# areg payout2 manag salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# areg payout2 c.manag##c.Mgmt_own salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# Out:
#   [1]              "/home/kennesaw/Sunay/adofiles"
#   [2]  (BASE)      "/usr/local/sas/stata16/ado/base/"
#   [3]  (SITE)      "/usr/local/sas/ado/"
#   [4]              "."
#   [5]  (PERSONAL)  "~/ado/personal/"
#   [6]  (PLUS)      "~/ado/plus/"
#   [7]  (OLDPLACE)  "~/ado/"
# (203 observations deleted)
# (29 observations deleted)
#
#     Variable |        Obs        Mean    Std. Dev.       Min        Max
# -------------+---------------------------------------------------------
# mgmt_owner~p |      1,942    .3791935    .6562334          0          3
#     Mgmt_own |      1,942    .1753339    .3173312          0          1
#
# Linear regression, absorbing indicators         Number of obs     =      1,928
# Absorbed variable: fyear                        No. of categories =         41
#                                                 F(   5,    447)   =       1.52
#                                                 Prob > F          =     0.1823
# ...

# %%
# %%stata
# adopath++ "/home/kennesaw/Sunay/adofiles"
#
# use "/home/kennesaw/Sunay/Dividends/withinprivates.dta", clear
#
# gen group1 = manag+employ
# gen group2 = pe1+pe2
#
# drop if (group1+group2==0)
#
# areg div2 group1 salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# areg div2 c.group1##c.Mgmt_own salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
#
# areg repurch2 group1 salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# areg repurch2 c.group1##c.Mgmt_own salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
#
# areg payout2 group1 salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# areg payout2 c.group1##c.Mgmt_own salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# Out:
#   [1]              "/home/kennesaw/Sunay/adofiles"
#   [2]  (BASE)      "/usr/local/sas/stata16/ado/base/"
#   [3]  (SITE)      "/usr/local/sas/ado/"
#   [4]              "."
#   [5]  (PERSONAL)  "~/ado/personal/"
#   [6]  (PLUS)      "~/ado/plus/"
#   [7]  (OLDPLACE)  "~/ado/"
# (29 observations deleted)
#
# Linear regression, absorbing indicators         Number of obs     =      2,131
# Absorbed variable: fyear                        No. of categories =         42
#                                                 F(   5,    465)   =       2.77
#                                                 Prob > F          =     0.0178
#                                                 R-squared         =     0.1536
#                                                 Adj R-squared     =     0.1349
#                                                 Root MSE          =     0.0431
#
#                                 (Std. Err. adjusted for 466 clusters in gvkey)
# ...

# %% [raw]
# Within Group 2

# %%
# %%stata
# adopath++ "/home/kennesaw/Sunay/adofiles"
#
# use "/home/kennesaw/Sunay/Dividends/withinprivates.dta", clear
#
# gen group1 = manag+employ
# gen group2 = pe1+pe2
#
# drop if (group1+group2==0)
#
# drop if (group1>=1)
#
# areg div2 Mgmt_own salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# areg div2 c.pe1##c.Mgmt_own salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
#
# areg repurch2 Mgmt_own salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# areg repurch2 c.pe1##c.Mgmt_own salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
#
# areg payout2 Mgmt_own salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# areg payout2 c.pe1##c.Mgmt_own salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
#
# areg div2 c.pe1##c.Many_PE salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# areg repurch2 c.pe1##c.Many_PE salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# areg payout2 c.pe1##c.Many_PE salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# Out:
#   [1]              "/home/kennesaw/Sunay/adofiles"
#   [2]  (BASE)      "/usr/local/sas/stata16/ado/base/"
#   [3]  (SITE)      "/usr/local/sas/ado/"
#   [4]              "."
#   [5]  (PERSONAL)  "~/ado/personal/"
#   [6]  (PLUS)      "~/ado/plus/"
#   [7]  (OLDPLACE)  "~/ado/"
# (29 observations deleted)
# (773 observations deleted)
#
# Linear regression, absorbing indicators         Number of obs     =      1,361
# Absorbed variable: fyear                        No. of categories =         37
#                                                 F(   5,    347)   =       0.83
#                                                 Prob > F          =     0.5260
#                                                 R-squared         =     0.1313
#                                                 Adj R-squared     =     0.1043
#                                                 Root MSE          =     0.0380
#
#                                 (Std. Err. adjusted for 348 clusters in gvkey)
# ...

# %% [raw]
# Within Group 1

# %%
# %%stata
# adopath++ "/home/kennesaw/Sunay/adofiles"
#
# use "/home/kennesaw/Sunay/Dividends/withinprivates.dta", clear
#
# gen group1 = manag+employ
# gen group2 = pe1+pe2
#
# drop if (group1+group2==0)
#
# drop if (group2>=1)
#
# areg div2 Mgmt_own salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# areg div2 c.manag##c.Mgmt_own salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
#
#
# areg repurch2 Mgmt_own salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# areg repurch2 c.manag##c.Mgmt_own salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
#
#
# areg payout2 Mgmt_own salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# areg payout2 c.manag##c.Mgmt_own salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# Out:
#   [1]              "/home/kennesaw/Sunay/adofiles"
#   [2]  (BASE)      "/usr/local/sas/stata16/ado/base/"
#   [3]  (SITE)      "/usr/local/sas/ado/"
#   [4]              "."
#   [5]  (PERSONAL)  "~/ado/personal/"
#   [6]  (PLUS)      "~/ado/plus/"
#   [7]  (OLDPLACE)  "~/ado/"
# (29 observations deleted)
# (1,372 observations deleted)
#
# Linear regression, absorbing indicators         Number of obs     =        770
# Absorbed variable: fyear                        No. of categories =         42
#                                                 F(   5,    122)   =       1.61
#                                                 Prob > F          =     0.1624
#                                                 R-squared         =     0.2710
#                                                 Adj R-squared     =     0.2246
#                                                 Root MSE          =     0.0487
#
#                                 (Std. Err. adjusted for 123 clusters in gvkey)
# ...

# %% [raw]
# Mgmt ownership within Sub-groups

# %%
# %%stata
# adopath++ "/home/kennesaw/Sunay/adofiles"
#
# use "/home/kennesaw/Sunay/Dividends/withinprivates.dta", clear
#
# areg div2 Mgmt_own salgrowth logat da opprofit if manag==1, absorb(fyear) robust cluster(gvkey)
# areg repurch2 Mgmt_own salgrowth logat da opprofit if manag==1, absorb(fyear) robust cluster(gvkey)
# areg payout2 Mgmt_own salgrowth logat da opprofit if manag==1, absorb(fyear) robust cluster(gvkey)
#
# areg div2 Mgmt_own salgrowth logat da opprofit if employ==1, absorb(fyear) robust cluster(gvkey)
# areg repurch2 Mgmt_own salgrowth logat da opprofit if employ==1, absorb(fyear) robust cluster(gvkey)
# areg payout2 Mgmt_own salgrowth logat da opprofit if employ==1, absorb(fyear) robust cluster(gvkey)
#
# areg div2 Mgmt_own salgrowth logat da opprofit if pe1==1, absorb(fyear) robust cluster(gvkey)
# areg repurch2 Mgmt_own salgrowth logat da opprofit if pe1==1, absorb(fyear) robust cluster(gvkey)
# areg payout2 Mgmt_own salgrowth logat da opprofit if pe1==1, absorb(fyear) robust cluster(gvkey)
#
# areg div2 Mgmt_own salgrowth logat da opprofit if pe2==1, absorb(fyear) robust cluster(gvkey)
# areg repurch2 Mgmt_own salgrowth logat da opprofit if pe2==1, absorb(fyear) robust cluster(gvkey)
# areg payout2 Mgmt_own salgrowth logat da opprofit if pe2==1, absorb(fyear) robust cluster(gvkey)
# Out:
#   [1]              "/home/kennesaw/Sunay/adofiles"
#   [2]  (BASE)      "/usr/local/sas/stata16/ado/base/"
#   [3]  (SITE)      "/usr/local/sas/ado/"
#   [4]              "."
#   [5]  (PERSONAL)  "~/ado/personal/"
#   [6]  (PLUS)      "~/ado/plus/"
#   [7]  (OLDPLACE)  "~/ado/"
#
# Linear regression, absorbing indicators         Number of obs     =        567
# Absorbed variable: fyear                        No. of categories =         41
#                                                 F(   5,    103)   =       0.84
#                                                 Prob > F          =     0.5266
#                                                 R-squared         =     0.2853
#                                                 Adj R-squared     =     0.2236
#                                                 Root MSE          =     0.0553
#
#                                 (Std. Err. adjusted for 104 clusters in gvkey)
# ...

# %%
# %%stata
# adopath++ "/home/kennesaw/Sunay/adofiles"
#
# use "/home/kennesaw/Sunay/Dividends/withinprivates.dta", clear
#
# areg div2 c.manag##c.Mgmt_own salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# areg repurch2 c.manag##c.Mgmt_own salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# areg payout2 c.manag##c.Mgmt_own salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
#
# areg div2 c.employ##c.Mgmt_own salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# areg repurch2 c.employ##c.Mgmt_own salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# areg payout2 c.employ##c.Mgmt_own salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
#
# areg div2 c.pe1##c.Mgmt_own salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# areg repurch2 c.pe1##c.Mgmt_own salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# areg payout2 c.pe1##c.Mgmt_own salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
#
# areg div2 c.pe2##c.Mgmt_own salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# areg repurch2 c.pe2##c.Mgmt_own salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# areg payout2 c.pe2##c.Mgmt_own salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# Out:
#   [1]              "/home/kennesaw/Sunay/adofiles"
#   [2]  (BASE)      "/usr/local/sas/stata16/ado/base/"
#   [3]  (SITE)      "/usr/local/sas/ado/"
#   [4]              "."
#   [5]  (PERSONAL)  "~/ado/personal/"
#   [6]  (PLUS)      "~/ado/plus/"
#   [7]  (OLDPLACE)  "~/ado/"
#
# Linear regression, absorbing indicators         Number of obs     =      2,160
# Absorbed variable: fyear                        No. of categories =         42
#                                                 F(   7,    470)   =       2.08
#                                                 Prob > F          =     0.0441
#                                                 R-squared         =     0.1551
#                                                 Adj R-squared     =     0.1359
#                                                 Root MSE          =     0.0429
#
#                                       (Std. Err. adjusted for 471 clusters in gvkey)
# ...
