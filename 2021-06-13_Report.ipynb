# %%
import ipystata
from ipystata.config import config_stata
config_stata('/usr/local/bin/stata')
# Out:
# IPyStata is loaded in batch mode.

# %% [markdown]
# ANNUAL

# %% [markdown]
# Model change in dividends

# %%
# %%stata
# adopath++ "/home/kennesaw/Sunay/adofiles"
#
# use "/home/kennesaw/Sunay/Dividends/levelfull.dta", clear
#
# areg chgdps chgeps if private==0, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel replace
#
# areg chgdps chgeps if private==1, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# use "/home/kennesaw/Sunay/Dividends/withinprivates.dta", clear
#
# areg chgdps chgeps if manag==1, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# areg chgdps chgeps if employ==1, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# areg chgdps chgeps if pe1==1, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# areg chgdps chgeps if pe2==1, absorb(fyear) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
# Out:
#   [1]              "/home/kennesaw/Sunay/adofiles"
#   [2]  (BASE)      "/usr/local/sas/stata16/ado/base/"
#   [3]  (SITE)      "/usr/local/sas/ado/"
#   [4]              "."
#   [5]  (PERSONAL)  "~/ado/personal/"
#   [6]  (PLUS)      "~/ado/plus/"
#   [7]  (OLDPLACE)  "~/ado/"
#
# Linear regression, absorbing indicators         Number of obs     =    181,341
# Absorbed variable: fyear                        No. of categories =         35
#                                                 F(   1,  19219)   =      85.92
#                                                 Prob > F          =     0.0000
#                                                 R-squared         =     0.0167
#                                                 Adj R-squared     =     0.0165
#                                                 Root MSE          =     0.2674
#
#                              (Std. Err. adjusted for 19,220 clusters in gvkey)
# ...

# %%
# %%stata
# adopath++ "/home/kennesaw/Sunay/adofiles"
#
# use "/home/kennesaw/Sunay/Dividends/levelfull.dta", clear
# gen incdiv=0
# replace incdiv=1 if chgdps>0
# replace incdiv=. if chgdps==.
#
# logit incdiv chgeps i.fyear if private==0, robust cluster(gvkey)
# outreg2 using myfile,e(r2_p) stats (coef tstat) bdec(3) tdec(2) excel replace
#
# logit incdiv chgeps i.fyear if private==1, robust cluster(gvkey)
# outreg2 using myfile,e(r2_p) stats (coef tstat) bdec(3) tdec(2) excel append
#
#
# use "/home/kennesaw/Sunay/Dividends/withinprivates.dta", clear
# gen incdiv=0
# replace incdiv=1 if chgdps>0
# replace incdiv=. if chgdps==.
#
# logit incdiv chgeps i.fyear if manag==1, robust cluster(gvkey)
# outreg2 using myfile,e(r2_p) stats (coef tstat) bdec(3) tdec(2) excel append
#
# logit incdiv chgeps i.fyear if employ==1, robust cluster(gvkey)
# outreg2 using myfile,e(r2_p) stats (coef tstat) bdec(3) tdec(2) excel append
#
# logit incdiv chgeps i.fyear if pe1==1, robust cluster(gvkey)
# outreg2 using myfile,e(r2_p) stats (coef tstat) bdec(3) tdec(2) excel append
#
# logit incdiv chgeps i.fyear if pe2==1, robust cluster(gvkey)
# outreg2 using myfile,e(r2_p) stats (coef tstat) bdec(3) tdec(2) excel append
# Out:
#   [1]              "/home/kennesaw/Sunay/adofiles"
#   [2]  (BASE)      "/usr/local/sas/stata16/ado/base/"
#   [3]  (SITE)      "/usr/local/sas/ado/"
#   [4]              "."
#   [5]  (PERSONAL)  "~/ado/personal/"
#   [6]  (PLUS)      "~/ado/plus/"
#   [7]  (OLDPLACE)  "~/ado/"
# (44,162 real changes made)
# (7,747 real changes made, 7,747 to missing)
#
# Iteration 0:   log pseudolikelihood = -90552.952
# Iteration 1:   log pseudolikelihood =  -89292.14
# Iteration 2:   log pseudolikelihood =  -89270.03
# Iteration 3:   log pseudolikelihood = -89270.008
# Iteration 4:   log pseudolikelihood = -89270.008
#
# Logistic regression                             Number of obs     =    181,341
#                                                 Wald chi2(35)     =    1889.13
#                                                 Prob > chi2       =     0.0000
# Log pseudolikelihood = -89270.008               Pseudo R2         =     0.0142
#
# ...

# %% [raw]
# QUARTERLY

# %%
# %%stata
# adopath++ "/home/kennesaw/Sunay/adofiles"
#
# use "/home/kennesaw/Sunay/Dividends/levelfull_q.dta", clear
# egen quarter=group(datacqtr)
#
# areg chgdps chgeps if private==0, absorb(quarter) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel replace
#
# areg chgdps chgeps if private==1, absorb(quarter) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# use "/home/kennesaw/Sunay/Dividends/withinprivates_q.dta", clear
# egen quarter=group(datacqtr)
#
# areg chgdps chgeps if manag==1, absorb(quarter) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# areg chgdps chgeps if employ==1, absorb(quarter) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# areg chgdps chgeps if pe1==1, absorb(quarter) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
#
# areg chgdps chgeps if pe2==1, absorb(quarter) robust cluster(gvkey)
# outreg2 using myfile,e(r2_a) stats (coef tstat) bdec(3) tdec(2) excel append
# Out:
#   [1]              "/home/kennesaw/Sunay/adofiles"
#   [2]  (BASE)      "/usr/local/sas/stata16/ado/base/"
#   [3]  (SITE)      "/usr/local/sas/ado/"
#   [4]              "."
#   [5]  (PERSONAL)  "~/ado/personal/"
#   [6]  (PLUS)      "~/ado/plus/"
#   [7]  (OLDPLACE)  "~/ado/"
# (743 missing values generated)
#
# Linear regression, absorbing indicators         Number of obs     =    672,709
# Absorbed variable: quarter                      No. of categories =        144
#                                                 F(   1,  20390)   =       0.00
#                                                 Prob > F          =     0.9780
#                                                 R-squared         =     0.0709
#                                                 Adj R-squared     =     0.0708
#                                                 Root MSE          =     0.3114
#
#                              (Std. Err. adjusted for 20,391 clusters in gvkey)
# ...

# %%
# %%stata
# adopath++ "/home/kennesaw/Sunay/adofiles"
#
# use "/home/kennesaw/Sunay/Dividends/levelfull_q.dta", clear
# gen incdiv=0
# replace incdiv=1 if chgdps>0
# replace incdiv=. if chgdps==.
# egen quarter=group(datacqtr)
#
#
# logit incdiv chgeps i.quarter if private==0, robust cluster(gvkey)
# outreg2 using myfile,e(r2_p) stats (coef tstat) bdec(3) tdec(2) excel replace
#
# logit incdiv chgeps i.quarter if private==1, robust cluster(gvkey)
# outreg2 using myfile,e(r2_p) stats (coef tstat) bdec(3) tdec(2) excel append
#
#
# use "/home/kennesaw/Sunay/Dividends/withinprivates_q.dta", clear
# gen incdiv=0
# replace incdiv=1 if chgdps>0
# replace incdiv=. if chgdps==.
#
# egen quarter=group(datacqtr)
#
# logit incdiv chgeps i.quarter if manag==1, robust cluster(gvkey)
# outreg2 using myfile,e(r2_p) stats (coef tstat) bdec(3) tdec(2) excel append
#
# logit incdiv chgeps i.quarter if employ==1, robust cluster(gvkey)
# outreg2 using myfile,e(r2_p) stats (coef tstat) bdec(3) tdec(2) excel append
#
# logit incdiv chgeps i.quarter if pe1==1, robust cluster(gvkey)
# outreg2 using myfile,e(r2_p) stats (coef tstat) bdec(3) tdec(2) excel append
#
# logit incdiv chgeps i.quarter if pe2==1, robust cluster(gvkey)
# outreg2 using myfile,e(r2_p) stats (coef tstat) bdec(3) tdec(2) excel append
# Out:
#   [1]              "/home/kennesaw/Sunay/adofiles"
#   [2]  (BASE)      "/usr/local/sas/stata16/ado/base/"
#   [3]  (SITE)      "/usr/local/sas/ado/"
#   [4]              "."
#   [5]  (PERSONAL)  "~/ado/personal/"
#   [6]  (PLUS)      "~/ado/plus/"
#   [7]  (OLDPLACE)  "~/ado/"
# (189,133 real changes made)
# (45,745 real changes made, 45,745 to missing)
# (743 missing values generated)
#
# Iteration 0:   log pseudolikelihood =  -346883.5
# Iteration 1:   log pseudolikelihood = -333370.72
# Iteration 2:   log pseudolikelihood = -332674.74
# Iteration 3:   log pseudolikelihood = -332671.19
# Iteration 4:   log pseudolikelihood = -332671.19
#
# Logistic regression                             Number of obs     =    672,709
#                                                 Wald chi2(144)    =    3517.65
#                                                 Prob > chi2       =     0.0000
# Log pseudolikelihood = -332671.19               Pseudo R2         =     0.0410
#
# ...
