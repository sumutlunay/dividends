# %%
import ipystata
from ipystata.config import config_stata
config_stata('/usr/local/bin/stata')
# Out:
# IPyStata is loaded in batch mode.

# %% [markdown]
# ANNUAL

# %% [markdown]
# Model change in dividends

# %%
# %%stata
# adopath++ "/home/kennesaw/Sunay/adofiles"
#
# use "/home/kennesaw/Sunay/Dividends/withinprivates.dta", clear
#
# # gen group1 = manag+employ
# # gen group2 = pe1+pe2
#
# # areg chgdps lagdps eps, absorb(fyear) robust cluster(gvkey)
# # areg chgdps lagdps eps opprofit, absorb(fyear) robust cluster(gvkey)
# # areg chgdps lagdps eps cfo, absorb(fyear) robust cluster(gvkey)
#
# # areg chgdps group1 lagdps eps, absorb(fyear) robust cluster(gvkey)
# # areg chgdps c.group1##c.Mgmt_own lagdps eps, absorb(fyear) robust cluster(gvkey)
#
# # areg chgdps pe2 lagdps eps if group2==1, absorb(fyear) robust cluster(gvkey)
# # areg chgdps c.pe2##c.Mgmt_own lagdps eps if group2==1, absorb(fyear) robust cluster(gvkey)
#
# # areg chgpayoutps lagpayoutps eps, absorb(fyear) robust cluster(gvkey)
# # areg chgpayoutps lagpayoutps eps opprofit, absorb(fyear) robust cluster(gvkey)
# # areg chgpayoutps lagpayoutps eps cfo, absorb(fyear) robust cluster(gvkey)
#
#
# # areg chgpayoutps group1 lagpayoutps eps, absorb(fyear) robust cluster(gvkey)
# # areg chgpayoutps pe2 lagpayoutps eps if group2==1, absorb(fyear) robust cluster(gvkey)
# # areg chgpayoutps c.pe2##c.Mgmt_own lagpayoutps eps if group2==1, absorb(fyear) robust cluster(gvkey)
#
# areg chgdps Mgmt_own lagdps eps, absorb(fyear) robust cluster(gvkey)
# areg chgdps c.manag##c.Mgmt_own lagdps eps, absorb(fyear) robust cluster(gvkey)
# areg chgdps c.employ##c.Mgmt_own lagdps eps, absorb(fyear) robust cluster(gvkey)
# areg chgdps c.pe1##c.Mgmt_own lagdps eps, absorb(fyear) robust cluster(gvkey)
# areg chgdps c.pe2##c.Mgmt_own lagdps eps, absorb(fyear) robust cluster(gvkey)
#
# areg chgpayoutps Mgmt_own lagpayoutps eps, absorb(fyear) robust cluster(gvkey)
# areg chgpayoutps c.manag##c.Mgmt_own lagdps eps, absorb(fyear) robust cluster(gvkey)
# areg chgpayoutps c.employ##c.Mgmt_own lagdps eps, absorb(fyear) robust cluster(gvkey)
# areg chgpayoutps c.pe1##c.Mgmt_own lagdps eps, absorb(fyear) robust cluster(gvkey)
# areg chgpayoutps c.pe2##c.Mgmt_own lagdps eps, absorb(fyear) robust cluster(gvkey)
# Out:
#   [1]              "/home/kennesaw/Sunay/adofiles"
#   [2]  (BASE)      "/usr/local/sas/stata16/ado/base/"
#   [3]  (SITE)      "/usr/local/sas/ado/"
#   [4]              "."
#   [5]  (PERSONAL)  "~/ado/personal/"
#   [6]  (PLUS)      "~/ado/plus/"
#   [7]  (OLDPLACE)  "~/ado/"
# Unknown #commandUnknown #commandUnknown #commandUnknown #commandUnknown #commandUnknown #commandUnknown #commandUnknown #commandUnknown #commandUnknown #commandUnknown #commandUnknown #command
# . Unknown #commandUnknown #commandUnknown #command
# Linear regression, absorbing indicators         Number of obs     =        864
# Absorbed variable: fyear                        No. of categories =         42
#                                                 F(   3,    195)   =     131.02
#                                                 Prob > F          =     0.0000
#                                                 R-squared         =     0.3974
# ...

# %% [raw]
# QUARTERLY

# %%
# %%stata
# adopath++ "/home/kennesaw/Sunay/adofiles"
#
# use "/home/kennesaw/Sunay/Dividends/withinprivates_q.dta", clear
#
# gen group1 = manag+employ
# gen group2 = pe1+pe2
#
# # areg chgdps lagdps eps, absorb(fyear) robust cluster(gvkey)
# # areg chgdps lagdps eps opprofit, absorb(fyear) robust cluster(gvkey)
# # areg chgdps lagdps eps cfo, absorb(fyear) robust cluster(gvkey)
#
# # areg chgdps group1 lagdps eps, absorb(fyear) robust cluster(gvkey)
# # areg chgdps c.group1##c.Mgmt_own lagdps eps, absorb(fyear) robust cluster(gvkey)
#
# # areg chgdps pe2 lagdps eps if group2==1, absorb(fyear) robust cluster(gvkey)
# # areg chgdps c.pe2##c.Mgmt_own lagdps eps if group2==1, absorb(fyear) robust cluster(gvkey)
#
# # areg chgpayoutps lagpayoutps eps, absorb(fyear) robust cluster(gvkey)
# # areg chgpayoutps lagpayoutps eps opprofit, absorb(fyear) robust cluster(gvkey)
# # areg chgpayoutps lagpayoutps eps cfo, absorb(fyear) robust cluster(gvkey)
#
# # areg chgpayoutps group1 lagpayoutps eps, absorb(fyear) robust cluster(gvkey)
# # areg chgpayoutps pe2 lagpayoutps eps if group2==1, absorb(fyear) robust cluster(gvkey)
# # areg chgpayoutps c.pe2##c.Mgmt_own lagpayoutps eps if group2==1, absorb(fyear) robust cluster(gvkey)
#
# areg chgdps Mgmt_own lagdps eps, absorb(fyear) robust cluster(gvkey)
# areg chgdps c.manag##c.Mgmt_own lagdps eps, absorb(fyear) robust cluster(gvkey)
# areg chgdps c.employ##c.Mgmt_own lagdps eps, absorb(fyear) robust cluster(gvkey)
# areg chgdps c.pe1##c.Mgmt_own lagdps eps, absorb(fyear) robust cluster(gvkey)
# areg chgdps c.pe2##c.Mgmt_own lagdps eps, absorb(fyear) robust cluster(gvkey)
#
# areg chgpayoutps Mgmt_own lagpayoutps eps, absorb(fyear) robust cluster(gvkey)
# areg chgpayoutps c.manag##c.Mgmt_own lagdps eps, absorb(fyear) robust cluster(gvkey)
# areg chgpayoutps c.employ##c.Mgmt_own lagdps eps, absorb(fyear) robust cluster(gvkey)
# areg chgpayoutps c.pe1##c.Mgmt_own lagdps eps, absorb(fyear) robust cluster(gvkey)
# areg chgpayoutps c.pe2##c.Mgmt_own lagdps eps, absorb(fyear) robust cluster(gvkey)
# Out:
#   [1]              "/home/kennesaw/Sunay/adofiles"
#   [2]  (BASE)      "/usr/local/sas/stata16/ado/base/"
#   [3]  (SITE)      "/usr/local/sas/ado/"
#   [4]              "."
#   [5]  (PERSONAL)  "~/ado/personal/"
#   [6]  (PLUS)      "~/ado/plus/"
#   [7]  (OLDPLACE)  "~/ado/"
# Unknown #commandUnknown #commandUnknown #commandUnknown #commandUnknown #commandUnknown #commandUnknown #commandUnknown #commandUnknown #commandUnknown #commandUnknown #commandUnknown #commandUnknown #command
# Linear regression, absorbing indicators         Number of obs     =      7,943
# Absorbed variable: fyear                        No. of categories =         38
#                                                 F(   3,    483)   =       3.35
#                                                 Prob > F          =     0.0189
#                                                 R-squared         =     0.1852
#                                                 Adj R-squared     =     0.1811
# ...
