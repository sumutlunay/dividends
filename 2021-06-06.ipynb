# %%
import ipystata
from ipystata.config import config_stata
config_stata('/usr/local/bin/stata')

# %% [markdown]
# ANNUAL

# %% [raw]
# Full Model

# %%
# %%stata
# adopath++ "/home/kennesaw/Sunay/adofiles"
#
# use "/home/kennesaw/Sunay/Dividends/levelfull.dta", clear
#
# areg div2 private salgrowth logat da opprofit loss, absorb(fyear) robust cluster(gvkey)
# areg repurch2 private salgrowth logat da opprofit loss, absorb(fyear) robust cluster(gvkey)
# areg payout2 private salgrowth logat da opprofit loss, absorb(fyear) robust cluster(gvkey)
# Out:
#   [1]              "/home/kennesaw/Sunay/adofiles"
#   [2]  (BASE)      "/usr/local/sas/stata16/ado/base/"
#   [3]  (SITE)      "/usr/local/sas/ado/"
#   [4]              "."
#   [5]  (PERSONAL)  "~/ado/personal/"
#   [6]  (PLUS)      "~/ado/plus/"
#   [7]  (OLDPLACE)  "~/ado/"
#
# Linear regression, absorbing indicators         Number of obs     =    186,532
# Absorbed variable: fyear                        No. of categories =         35
#                                                 F(   6,  19749)   =     509.23
#                                                 Prob > F          =     0.0000
#                                                 R-squared         =     0.0936
#                                                 Adj R-squared     =     0.0934
#                                                 Root MSE          =     0.0241
#
#                              (Std. Err. adjusted for 19,750 clusters in gvkey)
# ...

# %% [raw]
# PSM

# %%
# %%stata
# adopath++ "/home/kennesaw/Sunay/adofiles"
#
# use "/home/kennesaw/Sunay/Dividends/levelfull.dta", clear
#
# logit private logat da int_cov loss intang ppe growth
# predict p
#
# egen gr=group(fyear ind3)
# gen ps = gr*10+p
#
# set seed 1984
# gen u=uniform()
# sort u
#
# psmatch2 private, pscore(ps) caliper(.1) noreplace neighbor(1)
# gen pair = _id if _treated==0
# replace pair = _n1 if _treated==1
# bysort pair: egen paircount = count(pair)
# drop if paircount !=2
#
# areg div2 private salgrowth logat da opprofit loss, absorb(fyear) robust cluster(gvkey)
# areg repurch2 private salgrowth logat da opprofit loss, absorb(fyear) robust cluster(gvkey)
# areg payout2 private salgrowth logat da opprofit loss, absorb(fyear) robust cluster(gvkey)
# Out:
#   [1]              "/home/kennesaw/Sunay/adofiles"
#   [2]  (BASE)      "/usr/local/sas/stata16/ado/base/"
#   [3]  (SITE)      "/usr/local/sas/ado/"
#   [4]              "."
#   [5]  (PERSONAL)  "~/ado/personal/"
#   [6]  (PLUS)      "~/ado/plus/"
#   [7]  (OLDPLACE)  "~/ado/"
#
# Iteration 0:   log likelihood = -11069.121
# Iteration 1:   log likelihood =  -10991.85
# Iteration 2:   log likelihood = -10342.692
# Iteration 3:   log likelihood = -10329.085
# Iteration 4:   log likelihood = -10307.063
# Iteration 5:   log likelihood = -10305.313
# Iteration 6:   log likelihood = -10305.273
# Iteration 7:   log likelihood = -10305.273
#
# Logistic regression                             Number of obs     =    157,374
#                                                 LR chi2(7)        =    1527.70
#                                                 Prob > chi2       =     0.0000
# Log likelihood = -10305.273                     Pseudo R2         =     0.0690
#
# ...

# %% [raw]
# Within Privates

# %%
# %%stata
# adopath++ "/home/kennesaw/Sunay/adofiles"
#
# use "/home/kennesaw/Sunay/Dividends/withinprivates.dta", clear
#
# sum Mgmt_own if pe1==1
# sum Mgmt_own if pe2==1
# sum Mgmt_own if manag==1
# sum Mgmt_own if employ==1
#
#
# gen group1 = manag+employ
# gen group2 = pe1+pe2
#
# drop if (group1+group2==0)
# drop if employ==1
#
# # areg div2 group1 salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# # areg repurch2 group1 salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# # areg payout2 group1 salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
#
# # areg div2 c.manag##c.Mgmt_own salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# # areg repurch2 c.manag##c.Mgmt_own salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# # areg payout2 c.manag##c.Mgmt_own salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
#
# # areg div2 c.manag##c.mgmt_ownership salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# # areg repurch2 c.manag##c.mgmt_ownership salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# # areg payout2 c.manag##c.mgmt_ownership salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
#
# # areg div2 c.pe1##c.Mgmt_own salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# # areg repurch2 c.pe1##c.Mgmt_own salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# # areg payout2 c.pe1##c.Mgmt_own salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
#
# areg div2 Many_PE salgrowth logat da opprofit if group2==1, absorb(fyear) robust cluster(gvkey)
# areg repurch2 Many_PE salgrowth logat da opprofit if group2==1, absorb(fyear) robust cluster(gvkey)
# areg payout2 Many_PE salgrowth logat da opprofit if group2==1, absorb(fyear) robust cluster(gvkey)
#
# areg div2 largepe salgrowth logat da opprofit if group2==1, absorb(fyear) robust cluster(gvkey)
# areg repurch2 largepe salgrowth logat da opprofit if group2==1, absorb(fyear) robust cluster(gvkey)
# areg payout2 largepe salgrowth logat da opprofit if group2==1, absorb(fyear) robust cluster(gvkey)
# Out:
#   [1]              "/home/kennesaw/Sunay/adofiles"
#   [2]  (BASE)      "/usr/local/sas/stata16/ado/base/"
#   [3]  (SITE)      "/usr/local/sas/ado/"
#   [4]              "."
#   [5]  (PERSONAL)  "~/ado/personal/"
#   [6]  (PLUS)      "~/ado/plus/"
#   [7]  (OLDPLACE)  "~/ado/"
#
#     Variable |        Obs        Mean    Std. Dev.       Min        Max
# -------------+---------------------------------------------------------
#     Mgmt_own |      1,440    .0458866    .0768661          0       .522
#
#     Variable |        Obs        Mean    Std. Dev.       Min        Max
# -------------+---------------------------------------------------------
#     Mgmt_own |        228    .1661833    .2315642          0       .943
#
#     Variable |        Obs        Mean    Std. Dev.       Min        Max
# -------------+---------------------------------------------------------
#     Mgmt_own |        621    .4855274    .4504957          0          1
#
# ...

# %% [raw]
# Going Public

# %%
# %%stata
# adopath++ "/home/kennesaw/Sunay/adofiles"
#
# use "/home/kennesaw/Sunay/Dividends/gopublic.dta", clear
#
# areg div2 private salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# areg repurch2 private salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# areg payout2 private salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# Out:
#   [1]              "/home/kennesaw/Sunay/adofiles"
#   [2]  (BASE)      "/usr/local/sas/stata16/ado/base/"
#   [3]  (SITE)      "/usr/local/sas/ado/"
#   [4]              "."
#   [5]  (PERSONAL)  "~/ado/personal/"
#   [6]  (PLUS)      "~/ado/plus/"
#   [7]  (OLDPLACE)  "~/ado/"
#
# Linear regression, absorbing indicators         Number of obs     =      2,030
# Absorbed variable: fyear                        No. of categories =         35
#                                                 F(   5,    158)   =       1.05
#                                                 Prob > F          =     0.3879
#                                                 R-squared         =     0.1022
#                                                 Adj R-squared     =     0.0846
#                                                 Root MSE          =     0.0298
#
#                                 (Std. Err. adjusted for 159 clusters in gvkey)
# ...

# %% [raw]
# Going Private

# %%
# %%stata
# adopath++ "/home/kennesaw/Sunay/adofiles"
#
# use "/home/kennesaw/Sunay/Dividends/goprivate.dta", clear
#
# areg div2 private salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# areg repurch2 private salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# areg payout2 private salgrowth logat da opprofit, absorb(fyear) robust cluster(gvkey)
# Out:
#   [1]              "/home/kennesaw/Sunay/adofiles"
#   [2]  (BASE)      "/usr/local/sas/stata16/ado/base/"
#   [3]  (SITE)      "/usr/local/sas/ado/"
#   [4]              "."
#   [5]  (PERSONAL)  "~/ado/personal/"
#   [6]  (PLUS)      "~/ado/plus/"
#   [7]  (OLDPLACE)  "~/ado/"
#
# Linear regression, absorbing indicators         Number of obs     =      2,752
# Absorbed variable: fyear                        No. of categories =         35
#                                                 F(   5,    197)   =       2.74
#                                                 Prob > F          =     0.0205
#                                                 R-squared         =     0.0490
#                                                 Adj R-squared     =     0.0353
#                                                 Root MSE          =     0.0304
#
#                                 (Std. Err. adjusted for 198 clusters in gvkey)
# ...
